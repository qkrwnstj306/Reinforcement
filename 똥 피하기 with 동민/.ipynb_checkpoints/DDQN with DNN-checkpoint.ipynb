# %%
import torch
import collections # collections 모듈에 있는 deque를 사용하기 위함
#dequq는 double-ended queue로써, queue와 stack의 기능을 다 쓸 수 있다.

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import random
import numpy as np
import copy

# %%
class enva():
    def __init__(self):
        self.height = 10
        self.width = 10
        self.num_obstacle_range =5
        self.num_obstacle_range_min = 3
        self.turn = 0
        self.position = int(round(self.width/2))
        self.map = np.array([[0.0 for j in range(self.width)] for i in range(self.height)])
        self.map[self.height-1][self.position] = 2.
        self.done = False
        
    def step(self, key):
        #obstacle down
        i = self.height - 2
        while(i>=0):
            self.map[i+1] = self.map[i]
            i -= 1
        #obstacle init(first_line)
        self.map[0] = np.array([0 for j in range(self.width)])
        #obstacle making
        num_obstacle = random.randrange(self.num_obstacle_range_min,self.num_obstacle_range)
        i = 0
        while(i < num_obstacle):
            position_obstacle = random.randrange(0,self.width)
            if (self.map[0][position_obstacle] == 1.0):
                continue
            self.map[0][position_obstacle] = 1.0
            i += 1
        #big_obstacle
        big_obstacle = random.randrange(0,20)
        if(big_obstacle == -1): ############### 1로 바꾸면 큰 똥이 생긴다.
            big_obstacle = random.randrange(1,self.width-1)
            for j in range(3):
                for k in range(-1,2):
                    self.map[j][big_obstacle + k] = 1.
        #player position
        reward = 1
        # 0 : 왼쪽, 1 : 가만히, 2 : 오른쪽
        if key == 0:
            if(self.position>0):
                self.position -= 1
            
        if key == 1:
            pass      
        if key == 2:
            if(self.position<self.width-1):
                self.position += 1
                  
        if (self.map[self.height-1][self.position] == 1.0):
                    reward = 0
                    self.done = True
                    #print("====Game Over====")
                        
        self.map[self.height-1][self.position] = 2.0
        #reward(turn(time))
        self.turn += 1
        
        return torch.flatten(torch.tensor(self.map),0), reward, self.done, _ 

    def reset(self):
        self.turn = 0
        self.position = round(self.width/2)
        self.map = np.array([[0.0 for j in range(self.width)] for i in range(self.height)])
        self.map[self.height-1][self.position] = 2.0
        self.done = False
        
        return torch.flatten(torch.tensor(self.map),0)

# %%
#nerual network setting -> good performance
#hyperparameters
buffer_size =100000   #5000 # environment's size에 맞춰서 setting 
batch_size = 64 #32   
gamma = 0.99  # Large future weight

class Agent(nn.Module):
    def __init__(self):
        super(Agent,self).__init__()
        self.fc1 = nn.Linear(100,128)
        self.fc2 = nn.Linear(128,128)
        self.fc3 = nn.Linear(128,128)
        self.fc4 = nn.Linear(128,128)
        self.fc5 = nn.Linear(128,3)  # 좌우, 제자리
  
    def forward(self,x):
        
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = self.fc5(x)
        return x
  
  
    def select_action(self,state,eps):   # state, reward를 받으면 action이 나오는 relation. 
                                        # but reward는 memory를 통해 사용하므로 state를 받아서 action을 뽑는다.

        coin = random.random() # 0~1
        out_value = self.forward(state) # 
        if coin < eps:   # random action
            a = random.randint(0,2) # 0 ,1 ,2 choice
        else : # optimize action
            a = torch.argmax(out_value).item() # a는 tensor가 아닌 int로 들어가야 한다.
                                               # 둘 중 높은 value를 가진 index가 action이다. 
        return a

class replay_buffer():
    def __init__(self):
        self.buffer = collections.deque(maxlen = buffer_size)
    def put(self,input): # buffer에 store
        self.buffer.append(input) # dtype = tensor  4개가 한 묶음으로 들어가야됨

    def sampling(self,bat_ch): 
        mini_batch = random.sample(self.buffer,bat_ch) # bat_ch X 4 (list), dtype = tensor
                                                       # buffer에서 batch_size (현재 32)만큼 sampling을 한다.
        #s_list, a_list, r_prime_list, s_prime_list,done_mask_lst = [],[],[],[],[] # list로 각각을 저장할거임
        a_list, r_prime_list, done_mask_lst = [],[],[]
        s_list = torch.tensor([0 for i in range(100)],dtype = torch.float).unsqueeze(dim=0)
        s_prime_list = torch.tensor([0 for i in range(100)],dtype = torch.float).unsqueeze(dim=0)
        
        for transition in mini_batch:
              s, a, r_prime, s_prime,done_mask = transition
              
              
              # a : int, r_prime : float
              s_list = torch.cat([s_list,s.unsqueeze(dim=0)],dim=0) 
              s_prime_list = torch.cat([s_prime_list,s_prime.unsqueeze(dim=0)],dim=0)         
              #s_list.append(s)
              a_list.append([a]) # 열로 쌓는다
              r_prime_list.append([r_prime])
              #s_prime_list.append(s_prime)
              done_mask_lst.append([done_mask])
        s_list = s_list[1:,:]
        s_prime_list = s_prime_list[1:,:]      
        return torch.tensor(s_list, dtype=torch.float), torch.tensor(a_list), \
                       torch.tensor(r_prime_list), torch.tensor(s_prime_list, dtype=torch.float),torch.tensor(done_mask_lst)

    def size(self):
        return len(self.buffer)

def train(q,q_target,disk,optimizer):
    for i in range(10):
        s, a, r, s_prime,done_mask = disk.sampling(batch_size) # s : batch_size x 4    

        q_out = q(s) # current
        next_q_out = q(s_prime)
        next_q_tar_out = q_target(s_prime)
        q_a = q_out.gather(1,a)

        #print(next_q_out.size()) 32 by 2 
        #print(next_q_out.max(1)[0]) max value, max index가 나와서 [0]을 취했는데 DDQN에선 Qseta의 argmax를 뽑아야 하므로 [1]
        max_q_prime = next_q_tar_out.gather(1,next_q_out.max(1)[1].unsqueeze(1))
        #max_q_prime = q_target(s_prime).max(1)[0].unsqueeze(1) 기존의 DQN
        target = r + gamma * max_q_prime * done_mask
        
        loss = F.smooth_l1_loss(q_a,target.detach())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %%
env = enva()
q = Agent()
q_target = Agent()
q_target.load_state_dict(q.state_dict())
memory = replay_buffer()  

optimizer = optim.Adam(q.parameters(),lr = 0.0005)
score = 0.0
best_score = 0.
q.load_state_dict(torch.load('DQN_ddong_with_dongmin.pt'))
for epi in range(1000000):

    eps = max(0.002, 0.08 - 0.01*(epi/200)) #0,08
    s = env.reset()
   
    done = False
    one_score = 0
    while not done :
   
        a = q.select_action(s.float(),eps)
        s_prime,r,done,info = env.step(a)
        done_mask = 0.0 if done else 1.0  # termination이면 done을 0으로..
        memory.put((s,a,r,s_prime, done_mask)) # state, action, reward, state', done_mask
        s = copy.deepcopy(s_prime)
        
        score += r
        one_score += r
    if one_score > best_score:
        best_score = one_score
        print("...save model...")
        torch.save(q.state_dict(),"DQN_ddong_with_dongmin.pt")
        
        print("best score : ",best_score)
    if memory.size() >10000 : #3000
        train(q,q_target,memory,optimizer)

    if epi%100==0 and epi!=0:
        q_target.load_state_dict(q.state_dict())
        print("n_episode :{}, score : {:.1f}, n_buffer : {},eps = {}".format(
                                                        epi, score/100, memory.size(),eps))
        
        score = 0.0
# Out:
# ...save model...
# best score :  10
# ...save model...
# best score :  11
# ...save model...
# best score :  12
# ...save model...
# best score :  18
# ...save model...
# best score :  22
# ...save model...
# best score :  33
# n_episode :100, score : 11.3, n_buffer : 1232,eps = 0.075
# n_episode :200, score : 10.9, n_buffer : 2421,eps = 0.07
# n_episode :300, score : 11.0, n_buffer : 3621,eps = 0.065
# n_episode :400, score : 10.8, n_buffer : 4805,eps = 0.06
# n_episode :500, score : 10.7, n_buffer : 5978,eps = 0.055
# n_episode :600, score : 11.0, n_buffer : 7179,eps = 0.05
# n_episode :700, score : 10.6, n_buffer : 8343,eps = 0.045
# n_episode :800, score : 11.0, n_buffer : 9540,eps = 0.04
# /tmp/ipykernel_1692662/3334213522.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(s_list, dtype=torch.float), torch.tensor(a_list), \
# /tmp/ipykernel_1692662/3334213522.py:67: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(r_prime_list), torch.tensor(s_prime_list, dtype=torch.float),torch.tensor(done_mask_lst)
# n_episode :900, score : 12.3, n_buffer : 10869,eps = 0.035
# ...save model...
# best score :  34
# n_episode :1000, score : 13.8, n_buffer : 12346,eps = 0.03
# ...save model...
# best score :  35
# n_episode :1100, score : 14.0, n_buffer : 13843,eps = 0.025
# ...save model...
# best score :  48
# n_episode :1200, score : 13.7, n_buffer : 15315,eps = 0.020000000000000004
# n_episode :1300, score : 15.0, n_buffer : 16913,eps = 0.015
# n_episode :1400, score : 13.5, n_buffer : 18361,eps = 0.009999999999999995
# n_episode :1500, score : 14.8, n_buffer : 19943,eps = 0.0050000000000000044
# n_episode :1600, score : 16.1, n_buffer : 21651,eps = 0.002
# ...save model...
# best score :  50
# ...save model...
# best score :  60
# n_episode :1700, score : 17.1, n_buffer : 23457,eps = 0.002
# n_episode :1800, score : 17.3, n_buffer : 25289,eps = 0.002
# n_episode :1900, score : 15.8, n_buffer : 26973,eps = 0.002
# n_episode :2000, score : 16.5, n_buffer : 28720,eps = 0.002
# n_episode :2100, score : 16.4, n_buffer : 30465,eps = 0.002
# n_episode :2200, score : 17.1, n_buffer : 32272,eps = 0.002
# n_episode :2300, score : 18.2, n_buffer : 34192,eps = 0.002
# n_episode :2400, score : 18.2, n_buffer : 36116,eps = 0.002
# n_episode :2500, score : 16.5, n_buffer : 37866,eps = 0.002
# n_episode :2600, score : 17.1, n_buffer : 39681,eps = 0.002
# n_episode :2700, score : 16.9, n_buffer : 41474,eps = 0.002
# n_episode :2800, score : 18.0, n_buffer : 43370,eps = 0.002
# n_episode :2900, score : 19.4, n_buffer : 45406,eps = 0.002
# ...save model...
# best score :  65
# n_episode :3000, score : 19.1, n_buffer : 47419,eps = 0.002
# n_episode :3100, score : 18.3, n_buffer : 49346,eps = 0.002
# n_episode :3200, score : 18.8, n_buffer : 51326,eps = 0.002
# ...save model...
# best score :  74
# n_episode :3300, score : 19.7, n_buffer : 53399,eps = 0.002
# n_episode :3400, score : 19.8, n_buffer : 55479,eps = 0.002
# n_episode :3500, score : 20.4, n_buffer : 57614,eps = 0.002
# n_episode :3600, score : 20.9, n_buffer : 59806,eps = 0.002
# ...save model...
# best score :  76
# n_episode :3700, score : 22.8, n_buffer : 62182,eps = 0.002
# n_episode :3800, score : 21.9, n_buffer : 64467,eps = 0.002
# ...save model...
# best score :  84
# n_episode :3900, score : 20.6, n_buffer : 66628,eps = 0.002
# n_episode :4000, score : 21.0, n_buffer : 68825,eps = 0.002
# n_episode :4100, score : 22.0, n_buffer : 71129,eps = 0.002
# ...save model...
# best score :  87
# n_episode :4200, score : 25.3, n_buffer : 73758,eps = 0.002
# n_episode :4300, score : 24.5, n_buffer : 76304,eps = 0.002
# ...save model...
# best score :  113
# n_episode :4400, score : 26.6, n_buffer : 79062,eps = 0.002
# n_episode :4500, score : 22.8, n_buffer : 81444,eps = 0.002
# n_episode :4600, score : 23.1, n_buffer : 83855,eps = 0.002
# n_episode :4700, score : 23.4, n_buffer : 86299,eps = 0.002
# n_episode :4800, score : 25.6, n_buffer : 88961,eps = 0.002
# ...save model...
# best score :  119
# n_episode :4900, score : 25.4, n_buffer : 91598,eps = 0.002
# n_episode :5000, score : 30.4, n_buffer : 94739,eps = 0.002
# n_episode :5100, score : 29.7, n_buffer : 97812,eps = 0.002
# n_episode :5200, score : 29.4, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  150
# n_episode :5300, score : 31.2, n_buffer : 100000,eps = 0.002
# n_episode :5400, score : 31.2, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  165
# n_episode :5500, score : 32.5, n_buffer : 100000,eps = 0.002
# n_episode :5600, score : 31.0, n_buffer : 100000,eps = 0.002
# n_episode :5700, score : 36.2, n_buffer : 100000,eps = 0.002
# n_episode :5800, score : 34.1, n_buffer : 100000,eps = 0.002
# n_episode :5900, score : 40.9, n_buffer : 100000,eps = 0.002
# n_episode :6000, score : 39.7, n_buffer : 100000,eps = 0.002
# n_episode :6100, score : 35.5, n_buffer : 100000,eps = 0.002
# n_episode :6200, score : 38.6, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  166
# ...save model...
# best score :  178
# n_episode :6300, score : 43.6, n_buffer : 100000,eps = 0.002
# n_episode :6400, score : 39.1, n_buffer : 100000,eps = 0.002
# n_episode :6500, score : 53.4, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  234
# ...save model...
# best score :  235
# n_episode :6600, score : 54.9, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  334
# n_episode :6700, score : 64.4, n_buffer : 100000,eps = 0.002
# n_episode :6800, score : 55.4, n_buffer : 100000,eps = 0.002
# n_episode :6900, score : 54.8, n_buffer : 100000,eps = 0.002
# n_episode :7000, score : 62.6, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  358
# n_episode :7100, score : 64.2, n_buffer : 100000,eps = 0.002
# n_episode :7200, score : 64.2, n_buffer : 100000,eps = 0.002
# n_episode :7300, score : 65.9, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  364
# n_episode :7400, score : 72.0, n_buffer : 100000,eps = 0.002
# n_episode :7500, score : 80.3, n_buffer : 100000,eps = 0.002
# n_episode :7600, score : 64.7, n_buffer : 100000,eps = 0.002
# n_episode :7700, score : 83.8, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  368
# ...save model...
# best score :  371
# ...save model...
# best score :  442
# n_episode :7800, score : 78.8, n_buffer : 100000,eps = 0.002
# n_episode :7900, score : 80.1, n_buffer : 100000,eps = 0.002
# n_episode :8000, score : 92.6, n_buffer : 100000,eps = 0.002
# n_episode :8100, score : 70.8, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  477
# n_episode :8200, score : 92.3, n_buffer : 100000,eps = 0.002
# n_episode :8300, score : 89.5, n_buffer : 100000,eps = 0.002
# n_episode :8400, score : 77.5, n_buffer : 100000,eps = 0.002
# n_episode :8500, score : 84.8, n_buffer : 100000,eps = 0.002
# n_episode :8600, score : 79.0, n_buffer : 100000,eps = 0.002
# n_episode :8700, score : 92.2, n_buffer : 100000,eps = 0.002
# n_episode :8800, score : 74.8, n_buffer : 100000,eps = 0.002
# n_episode :8900, score : 81.4, n_buffer : 100000,eps = 0.002
# n_episode :9000, score : 84.9, n_buffer : 100000,eps = 0.002
# n_episode :9100, score : 70.9, n_buffer : 100000,eps = 0.002
# n_episode :9200, score : 80.9, n_buffer : 100000,eps = 0.002
# n_episode :9300, score : 59.4, n_buffer : 100000,eps = 0.002
# n_episode :9400, score : 85.6, n_buffer : 100000,eps = 0.002
# n_episode :9500, score : 68.1, n_buffer : 100000,eps = 0.002
# n_episode :9600, score : 71.7, n_buffer : 100000,eps = 0.002
# n_episode :9700, score : 75.8, n_buffer : 100000,eps = 0.002
# n_episode :9800, score : 89.3, n_buffer : 100000,eps = 0.002
# n_episode :9900, score : 69.0, n_buffer : 100000,eps = 0.002
# n_episode :10000, score : 91.6, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  495
# n_episode :10100, score : 84.8, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  696
# n_episode :10200, score : 91.8, n_buffer : 100000,eps = 0.002
# n_episode :10300, score : 71.2, n_buffer : 100000,eps = 0.002
# n_episode :10400, score : 78.9, n_buffer : 100000,eps = 0.002
# n_episode :10500, score : 81.0, n_buffer : 100000,eps = 0.002
# n_episode :10600, score : 87.8, n_buffer : 100000,eps = 0.002
# n_episode :10700, score : 96.5, n_buffer : 100000,eps = 0.002
# n_episode :10800, score : 107.6, n_buffer : 100000,eps = 0.002
# n_episode :10900, score : 90.5, n_buffer : 100000,eps = 0.002
# n_episode :11000, score : 76.8, n_buffer : 100000,eps = 0.002
# n_episode :11100, score : 102.0, n_buffer : 100000,eps = 0.002
# n_episode :11200, score : 101.8, n_buffer : 100000,eps = 0.002
# n_episode :11300, score : 93.9, n_buffer : 100000,eps = 0.002
# n_episode :11400, score : 117.4, n_buffer : 100000,eps = 0.002
# n_episode :11500, score : 112.8, n_buffer : 100000,eps = 0.002
# n_episode :11600, score : 88.2, n_buffer : 100000,eps = 0.002
# n_episode :11700, score : 102.7, n_buffer : 100000,eps = 0.002
# n_episode :11800, score : 81.1, n_buffer : 100000,eps = 0.002
# n_episode :11900, score : 97.4, n_buffer : 100000,eps = 0.002
# n_episode :12000, score : 94.1, n_buffer : 100000,eps = 0.002
# n_episode :12100, score : 101.2, n_buffer : 100000,eps = 0.002
# n_episode :12200, score : 81.2, n_buffer : 100000,eps = 0.002
# n_episode :12300, score : 114.6, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  766
# n_episode :12400, score : 108.7, n_buffer : 100000,eps = 0.002
# n_episode :12500, score : 83.2, n_buffer : 100000,eps = 0.002
# n_episode :12600, score : 101.9, n_buffer : 100000,eps = 0.002
# n_episode :12700, score : 85.0, n_buffer : 100000,eps = 0.002
# n_episode :12800, score : 119.8, n_buffer : 100000,eps = 0.002
# n_episode :12900, score : 85.5, n_buffer : 100000,eps = 0.002
# n_episode :13000, score : 106.7, n_buffer : 100000,eps = 0.002
# n_episode :13100, score : 119.3, n_buffer : 100000,eps = 0.002
# n_episode :13200, score : 116.4, n_buffer : 100000,eps = 0.002
# n_episode :13300, score : 109.1, n_buffer : 100000,eps = 0.002
# n_episode :13400, score : 120.5, n_buffer : 100000,eps = 0.002
# n_episode :13500, score : 114.9, n_buffer : 100000,eps = 0.002
# n_episode :13600, score : 109.5, n_buffer : 100000,eps = 0.002
# n_episode :13700, score : 86.8, n_buffer : 100000,eps = 0.002
# n_episode :13800, score : 93.2, n_buffer : 100000,eps = 0.002
# n_episode :13900, score : 106.5, n_buffer : 100000,eps = 0.002
# n_episode :14000, score : 77.4, n_buffer : 100000,eps = 0.002
# n_episode :14100, score : 111.5, n_buffer : 100000,eps = 0.002
# n_episode :14200, score : 80.0, n_buffer : 100000,eps = 0.002
# n_episode :14300, score : 122.6, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  813
# n_episode :14400, score : 110.5, n_buffer : 100000,eps = 0.002
# n_episode :14500, score : 116.2, n_buffer : 100000,eps = 0.002
# n_episode :14600, score : 103.0, n_buffer : 100000,eps = 0.002
# n_episode :14700, score : 109.4, n_buffer : 100000,eps = 0.002
# n_episode :14800, score : 103.7, n_buffer : 100000,eps = 0.002
# n_episode :14900, score : 98.1, n_buffer : 100000,eps = 0.002
# n_episode :15000, score : 70.7, n_buffer : 100000,eps = 0.002
# n_episode :15100, score : 68.1, n_buffer : 100000,eps = 0.002
# n_episode :15200, score : 96.7, n_buffer : 100000,eps = 0.002
# n_episode :15300, score : 70.9, n_buffer : 100000,eps = 0.002
# n_episode :15400, score : 105.3, n_buffer : 100000,eps = 0.002
# n_episode :15500, score : 86.3, n_buffer : 100000,eps = 0.002
# n_episode :15600, score : 62.2, n_buffer : 100000,eps = 0.002
# n_episode :15700, score : 58.7, n_buffer : 100000,eps = 0.002
# n_episode :15800, score : 90.9, n_buffer : 100000,eps = 0.002
# n_episode :15900, score : 115.2, n_buffer : 100000,eps = 0.002
# n_episode :16000, score : 105.4, n_buffer : 100000,eps = 0.002
# n_episode :16100, score : 148.8, n_buffer : 100000,eps = 0.002
# n_episode :16200, score : 116.2, n_buffer : 100000,eps = 0.002
# n_episode :16300, score : 105.9, n_buffer : 100000,eps = 0.002
# n_episode :16400, score : 99.6, n_buffer : 100000,eps = 0.002
# n_episode :16500, score : 101.2, n_buffer : 100000,eps = 0.002
# n_episode :16600, score : 129.3, n_buffer : 100000,eps = 0.002
# n_episode :16700, score : 106.7, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  859
# n_episode :16800, score : 100.7, n_buffer : 100000,eps = 0.002
# n_episode :16900, score : 116.1, n_buffer : 100000,eps = 0.002
# n_episode :17000, score : 104.2, n_buffer : 100000,eps = 0.002
# n_episode :17100, score : 145.4, n_buffer : 100000,eps = 0.002
# n_episode :17200, score : 115.5, n_buffer : 100000,eps = 0.002
# n_episode :17300, score : 140.6, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  1113
# n_episode :17400, score : 151.8, n_buffer : 100000,eps = 0.002
# n_episode :17500, score : 120.5, n_buffer : 100000,eps = 0.002
# n_episode :17600, score : 121.2, n_buffer : 100000,eps = 0.002
# n_episode :17700, score : 90.3, n_buffer : 100000,eps = 0.002
# n_episode :17800, score : 97.3, n_buffer : 100000,eps = 0.002
# n_episode :17900, score : 135.4, n_buffer : 100000,eps = 0.002
# n_episode :18000, score : 107.9, n_buffer : 100000,eps = 0.002
# n_episode :18100, score : 100.5, n_buffer : 100000,eps = 0.002
# n_episode :18200, score : 101.5, n_buffer : 100000,eps = 0.002
# n_episode :18300, score : 158.2, n_buffer : 100000,eps = 0.002
# n_episode :18400, score : 104.9, n_buffer : 100000,eps = 0.002
# n_episode :18500, score : 95.4, n_buffer : 100000,eps = 0.002
# n_episode :18600, score : 85.0, n_buffer : 100000,eps = 0.002
# n_episode :18700, score : 58.7, n_buffer : 100000,eps = 0.002
# n_episode :18800, score : 81.3, n_buffer : 100000,eps = 0.002
# n_episode :18900, score : 100.8, n_buffer : 100000,eps = 0.002
# n_episode :19000, score : 104.0, n_buffer : 100000,eps = 0.002
# n_episode :19100, score : 86.5, n_buffer : 100000,eps = 0.002
# n_episode :19200, score : 109.3, n_buffer : 100000,eps = 0.002
# n_episode :19300, score : 123.1, n_buffer : 100000,eps = 0.002
# n_episode :19400, score : 88.5, n_buffer : 100000,eps = 0.002
# n_episode :19500, score : 88.9, n_buffer : 100000,eps = 0.002
# n_episode :19600, score : 130.1, n_buffer : 100000,eps = 0.002
# n_episode :19700, score : 96.8, n_buffer : 100000,eps = 0.002
# n_episode :19800, score : 105.4, n_buffer : 100000,eps = 0.002
# n_episode :19900, score : 142.1, n_buffer : 100000,eps = 0.002
# n_episode :20000, score : 152.8, n_buffer : 100000,eps = 0.002
# n_episode :20100, score : 112.2, n_buffer : 100000,eps = 0.002
# n_episode :20200, score : 144.2, n_buffer : 100000,eps = 0.002
# n_episode :20300, score : 147.4, n_buffer : 100000,eps = 0.002
# n_episode :20400, score : 120.7, n_buffer : 100000,eps = 0.002
# n_episode :20500, score : 133.8, n_buffer : 100000,eps = 0.002
# n_episode :20600, score : 72.7, n_buffer : 100000,eps = 0.002
# n_episode :20700, score : 66.2, n_buffer : 100000,eps = 0.002
# n_episode :20800, score : 80.5, n_buffer : 100000,eps = 0.002
# n_episode :20900, score : 102.8, n_buffer : 100000,eps = 0.002
# n_episode :21000, score : 111.9, n_buffer : 100000,eps = 0.002
# n_episode :21100, score : 122.0, n_buffer : 100000,eps = 0.002
# n_episode :21200, score : 120.7, n_buffer : 100000,eps = 0.002
# n_episode :21300, score : 150.9, n_buffer : 100000,eps = 0.002
# n_episode :21400, score : 146.4, n_buffer : 100000,eps = 0.002
# n_episode :21500, score : 127.9, n_buffer : 100000,eps = 0.002
# n_episode :21600, score : 101.1, n_buffer : 100000,eps = 0.002
# n_episode :21700, score : 113.3, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  1140
# n_episode :21800, score : 149.2, n_buffer : 100000,eps = 0.002
# n_episode :21900, score : 84.9, n_buffer : 100000,eps = 0.002
# n_episode :22000, score : 97.6, n_buffer : 100000,eps = 0.002
# n_episode :22100, score : 90.3, n_buffer : 100000,eps = 0.002
# n_episode :22200, score : 129.8, n_buffer : 100000,eps = 0.002
# n_episode :22300, score : 94.1, n_buffer : 100000,eps = 0.002
# n_episode :22400, score : 100.8, n_buffer : 100000,eps = 0.002
# n_episode :22500, score : 110.3, n_buffer : 100000,eps = 0.002
# n_episode :22600, score : 175.1, n_buffer : 100000,eps = 0.002
# n_episode :22700, score : 148.8, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  1150
# n_episode :22800, score : 172.1, n_buffer : 100000,eps = 0.002
# n_episode :22900, score : 142.2, n_buffer : 100000,eps = 0.002
# n_episode :23000, score : 134.7, n_buffer : 100000,eps = 0.002
# n_episode :23100, score : 123.2, n_buffer : 100000,eps = 0.002
# n_episode :23200, score : 151.0, n_buffer : 100000,eps = 0.002
# n_episode :23300, score : 106.8, n_buffer : 100000,eps = 0.002
# n_episode :23400, score : 136.3, n_buffer : 100000,eps = 0.002
# n_episode :23500, score : 88.3, n_buffer : 100000,eps = 0.002
# n_episode :23600, score : 108.7, n_buffer : 100000,eps = 0.002
# n_episode :23700, score : 142.8, n_buffer : 100000,eps = 0.002
# n_episode :23800, score : 146.3, n_buffer : 100000,eps = 0.002
# n_episode :23900, score : 142.7, n_buffer : 100000,eps = 0.002
# n_episode :24000, score : 145.1, n_buffer : 100000,eps = 0.002
# n_episode :24100, score : 92.3, n_buffer : 100000,eps = 0.002
# n_episode :24200, score : 95.8, n_buffer : 100000,eps = 0.002
# n_episode :24300, score : 87.9, n_buffer : 100000,eps = 0.002
# n_episode :24400, score : 94.7, n_buffer : 100000,eps = 0.002
# n_episode :24500, score : 132.8, n_buffer : 100000,eps = 0.002
# n_episode :24600, score : 111.4, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  1188
# n_episode :24700, score : 107.6, n_buffer : 100000,eps = 0.002
# n_episode :24800, score : 135.6, n_buffer : 100000,eps = 0.002
# n_episode :24900, score : 131.7, n_buffer : 100000,eps = 0.002
# n_episode :25000, score : 86.6, n_buffer : 100000,eps = 0.002
# n_episode :25100, score : 79.2, n_buffer : 100000,eps = 0.002
# n_episode :25200, score : 74.8, n_buffer : 100000,eps = 0.002
# n_episode :25300, score : 107.6, n_buffer : 100000,eps = 0.002
# n_episode :25400, score : 117.7, n_buffer : 100000,eps = 0.002
# n_episode :25500, score : 102.2, n_buffer : 100000,eps = 0.002
# n_episode :25600, score : 120.2, n_buffer : 100000,eps = 0.002
# n_episode :25700, score : 137.0, n_buffer : 100000,eps = 0.002
# n_episode :25800, score : 111.3, n_buffer : 100000,eps = 0.002
# n_episode :25900, score : 136.8, n_buffer : 100000,eps = 0.002
# n_episode :26000, score : 107.9, n_buffer : 100000,eps = 0.002
# n_episode :26100, score : 90.9, n_buffer : 100000,eps = 0.002
# n_episode :26200, score : 109.4, n_buffer : 100000,eps = 0.002
# n_episode :26300, score : 112.0, n_buffer : 100000,eps = 0.002
# n_episode :26400, score : 93.5, n_buffer : 100000,eps = 0.002
# n_episode :26500, score : 123.9, n_buffer : 100000,eps = 0.002
# n_episode :26600, score : 96.4, n_buffer : 100000,eps = 0.002
# n_episode :26700, score : 136.1, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  1559
# n_episode :26800, score : 132.4, n_buffer : 100000,eps = 0.002
# n_episode :26900, score : 120.3, n_buffer : 100000,eps = 0.002
# n_episode :27000, score : 107.1, n_buffer : 100000,eps = 0.002
# n_episode :27100, score : 131.0, n_buffer : 100000,eps = 0.002
# n_episode :27200, score : 131.9, n_buffer : 100000,eps = 0.002
# n_episode :27300, score : 106.2, n_buffer : 100000,eps = 0.002
# n_episode :27400, score : 136.4, n_buffer : 100000,eps = 0.002
# n_episode :27500, score : 121.6, n_buffer : 100000,eps = 0.002
# n_episode :27600, score : 128.9, n_buffer : 100000,eps = 0.002
# n_episode :27700, score : 136.4, n_buffer : 100000,eps = 0.002
# n_episode :27800, score : 172.4, n_buffer : 100000,eps = 0.002
# n_episode :27900, score : 119.2, n_buffer : 100000,eps = 0.002
# n_episode :28000, score : 116.7, n_buffer : 100000,eps = 0.002
# n_episode :28100, score : 97.7, n_buffer : 100000,eps = 0.002
# n_episode :28200, score : 105.2, n_buffer : 100000,eps = 0.002
# n_episode :28300, score : 93.8, n_buffer : 100000,eps = 0.002
# n_episode :28400, score : 77.1, n_buffer : 100000,eps = 0.002
# n_episode :28500, score : 89.9, n_buffer : 100000,eps = 0.002
# n_episode :28600, score : 97.0, n_buffer : 100000,eps = 0.002
# n_episode :28700, score : 107.8, n_buffer : 100000,eps = 0.002
# n_episode :28800, score : 102.6, n_buffer : 100000,eps = 0.002
# n_episode :28900, score : 72.7, n_buffer : 100000,eps = 0.002
# n_episode :29000, score : 132.3, n_buffer : 100000,eps = 0.002
# n_episode :29100, score : 120.2, n_buffer : 100000,eps = 0.002
# n_episode :29200, score : 137.8, n_buffer : 100000,eps = 0.002
# n_episode :29300, score : 144.8, n_buffer : 100000,eps = 0.002
# n_episode :29400, score : 123.9, n_buffer : 100000,eps = 0.002
# n_episode :29500, score : 138.9, n_buffer : 100000,eps = 0.002
# n_episode :29600, score : 130.9, n_buffer : 100000,eps = 0.002
# n_episode :29700, score : 123.5, n_buffer : 100000,eps = 0.002
# n_episode :29800, score : 97.2, n_buffer : 100000,eps = 0.002
# n_episode :29900, score : 97.4, n_buffer : 100000,eps = 0.002
# n_episode :30000, score : 107.4, n_buffer : 100000,eps = 0.002
# n_episode :30100, score : 116.0, n_buffer : 100000,eps = 0.002
# n_episode :30200, score : 118.9, n_buffer : 100000,eps = 0.002
# n_episode :30300, score : 104.6, n_buffer : 100000,eps = 0.002
# n_episode :30400, score : 114.2, n_buffer : 100000,eps = 0.002
# n_episode :30500, score : 128.9, n_buffer : 100000,eps = 0.002
# n_episode :30600, score : 97.6, n_buffer : 100000,eps = 0.002
# n_episode :30700, score : 105.3, n_buffer : 100000,eps = 0.002
# n_episode :30800, score : 112.2, n_buffer : 100000,eps = 0.002
# n_episode :30900, score : 110.4, n_buffer : 100000,eps = 0.002
# n_episode :31000, score : 130.0, n_buffer : 100000,eps = 0.002
# n_episode :31100, score : 79.9, n_buffer : 100000,eps = 0.002
# n_episode :31200, score : 97.4, n_buffer : 100000,eps = 0.002
# n_episode :31300, score : 121.7, n_buffer : 100000,eps = 0.002
# n_episode :31400, score : 110.1, n_buffer : 100000,eps = 0.002
# n_episode :31500, score : 138.9, n_buffer : 100000,eps = 0.002
# n_episode :31600, score : 102.2, n_buffer : 100000,eps = 0.002
# n_episode :31700, score : 78.0, n_buffer : 100000,eps = 0.002
# n_episode :31800, score : 109.4, n_buffer : 100000,eps = 0.002
# n_episode :31900, score : 115.7, n_buffer : 100000,eps = 0.002
# n_episode :32000, score : 145.5, n_buffer : 100000,eps = 0.002
# n_episode :32100, score : 111.8, n_buffer : 100000,eps = 0.002
# n_episode :32200, score : 87.9, n_buffer : 100000,eps = 0.002
# n_episode :32300, score : 132.5, n_buffer : 100000,eps = 0.002
# n_episode :32400, score : 122.3, n_buffer : 100000,eps = 0.002
# n_episode :32500, score : 122.6, n_buffer : 100000,eps = 0.002
# n_episode :32600, score : 130.6, n_buffer : 100000,eps = 0.002
# n_episode :32700, score : 123.3, n_buffer : 100000,eps = 0.002
# n_episode :32800, score : 108.4, n_buffer : 100000,eps = 0.002
# n_episode :32900, score : 106.6, n_buffer : 100000,eps = 0.002
# n_episode :33000, score : 101.9, n_buffer : 100000,eps = 0.002
# n_episode :33100, score : 97.6, n_buffer : 100000,eps = 0.002
# n_episode :33200, score : 116.3, n_buffer : 100000,eps = 0.002
# n_episode :33300, score : 114.0, n_buffer : 100000,eps = 0.002
# n_episode :33400, score : 91.8, n_buffer : 100000,eps = 0.002
# n_episode :33500, score : 117.1, n_buffer : 100000,eps = 0.002
# n_episode :33600, score : 100.5, n_buffer : 100000,eps = 0.002
# n_episode :33700, score : 111.6, n_buffer : 100000,eps = 0.002
# n_episode :33800, score : 131.5, n_buffer : 100000,eps = 0.002
# n_episode :33900, score : 88.3, n_buffer : 100000,eps = 0.002
# n_episode :34000, score : 121.5, n_buffer : 100000,eps = 0.002
# n_episode :34100, score : 139.5, n_buffer : 100000,eps = 0.002
# n_episode :34200, score : 143.2, n_buffer : 100000,eps = 0.002
# n_episode :34300, score : 144.8, n_buffer : 100000,eps = 0.002
# n_episode :34400, score : 149.2, n_buffer : 100000,eps = 0.002
# n_episode :34500, score : 131.8, n_buffer : 100000,eps = 0.002
# n_episode :34600, score : 127.2, n_buffer : 100000,eps = 0.002
# n_episode :34700, score : 163.4, n_buffer : 100000,eps = 0.002
# n_episode :34800, score : 150.8, n_buffer : 100000,eps = 0.002
# n_episode :34900, score : 152.3, n_buffer : 100000,eps = 0.002
# n_episode :35000, score : 143.6, n_buffer : 100000,eps = 0.002
# n_episode :35100, score : 129.3, n_buffer : 100000,eps = 0.002
# n_episode :35200, score : 139.4, n_buffer : 100000,eps = 0.002
# n_episode :35300, score : 159.7, n_buffer : 100000,eps = 0.002
# n_episode :35400, score : 134.6, n_buffer : 100000,eps = 0.002
# n_episode :35500, score : 127.8, n_buffer : 100000,eps = 0.002
# n_episode :35600, score : 117.5, n_buffer : 100000,eps = 0.002
# n_episode :35700, score : 107.2, n_buffer : 100000,eps = 0.002
# n_episode :35800, score : 105.2, n_buffer : 100000,eps = 0.002
# n_episode :35900, score : 128.0, n_buffer : 100000,eps = 0.002
# n_episode :36000, score : 148.7, n_buffer : 100000,eps = 0.002
# n_episode :36100, score : 171.4, n_buffer : 100000,eps = 0.002
# n_episode :36200, score : 152.4, n_buffer : 100000,eps = 0.002
# n_episode :36300, score : 116.1, n_buffer : 100000,eps = 0.002
# n_episode :36400, score : 85.4, n_buffer : 100000,eps = 0.002
# n_episode :36500, score : 82.8, n_buffer : 100000,eps = 0.002
# n_episode :36600, score : 80.5, n_buffer : 100000,eps = 0.002
# n_episode :36700, score : 100.2, n_buffer : 100000,eps = 0.002
# n_episode :36800, score : 123.0, n_buffer : 100000,eps = 0.002
# n_episode :36900, score : 129.7, n_buffer : 100000,eps = 0.002
# n_episode :37000, score : 135.3, n_buffer : 100000,eps = 0.002
# n_episode :37100, score : 113.3, n_buffer : 100000,eps = 0.002
# n_episode :37200, score : 151.5, n_buffer : 100000,eps = 0.002
# n_episode :37300, score : 131.7, n_buffer : 100000,eps = 0.002
# n_episode :37400, score : 107.9, n_buffer : 100000,eps = 0.002
# n_episode :37500, score : 139.9, n_buffer : 100000,eps = 0.002
# n_episode :37600, score : 154.0, n_buffer : 100000,eps = 0.002
# n_episode :37700, score : 138.5, n_buffer : 100000,eps = 0.002
# n_episode :37800, score : 136.2, n_buffer : 100000,eps = 0.002
# n_episode :37900, score : 137.6, n_buffer : 100000,eps = 0.002
# n_episode :38000, score : 105.9, n_buffer : 100000,eps = 0.002
# n_episode :38100, score : 84.2, n_buffer : 100000,eps = 0.002
# n_episode :38200, score : 91.6, n_buffer : 100000,eps = 0.002
# n_episode :38300, score : 97.3, n_buffer : 100000,eps = 0.002
# n_episode :38400, score : 139.4, n_buffer : 100000,eps = 0.002
# n_episode :38500, score : 115.8, n_buffer : 100000,eps = 0.002
# n_episode :38600, score : 108.7, n_buffer : 100000,eps = 0.002
# n_episode :38700, score : 155.4, n_buffer : 100000,eps = 0.002
# n_episode :38800, score : 158.8, n_buffer : 100000,eps = 0.002
# n_episode :38900, score : 116.8, n_buffer : 100000,eps = 0.002
# n_episode :39000, score : 132.3, n_buffer : 100000,eps = 0.002
# n_episode :39100, score : 152.1, n_buffer : 100000,eps = 0.002
# n_episode :39200, score : 156.6, n_buffer : 100000,eps = 0.002
# n_episode :39300, score : 137.3, n_buffer : 100000,eps = 0.002
# n_episode :39400, score : 157.1, n_buffer : 100000,eps = 0.002
# n_episode :39500, score : 159.0, n_buffer : 100000,eps = 0.002
# n_episode :39600, score : 110.2, n_buffer : 100000,eps = 0.002
# n_episode :39700, score : 155.5, n_buffer : 100000,eps = 0.002
# n_episode :39800, score : 123.4, n_buffer : 100000,eps = 0.002
# n_episode :39900, score : 112.9, n_buffer : 100000,eps = 0.002
# n_episode :40000, score : 142.0, n_buffer : 100000,eps = 0.002
# n_episode :40100, score : 138.8, n_buffer : 100000,eps = 0.002
# n_episode :40200, score : 127.6, n_buffer : 100000,eps = 0.002
# n_episode :40300, score : 86.7, n_buffer : 100000,eps = 0.002
# n_episode :40400, score : 97.8, n_buffer : 100000,eps = 0.002
# n_episode :40500, score : 115.0, n_buffer : 100000,eps = 0.002
# n_episode :40600, score : 120.2, n_buffer : 100000,eps = 0.002
# n_episode :40700, score : 125.0, n_buffer : 100000,eps = 0.002
# n_episode :40800, score : 122.3, n_buffer : 100000,eps = 0.002
# n_episode :40900, score : 126.5, n_buffer : 100000,eps = 0.002
# n_episode :41000, score : 116.7, n_buffer : 100000,eps = 0.002
# n_episode :41100, score : 163.3, n_buffer : 100000,eps = 0.002
# n_episode :41200, score : 157.6, n_buffer : 100000,eps = 0.002
# n_episode :41300, score : 162.6, n_buffer : 100000,eps = 0.002
# n_episode :41400, score : 132.8, n_buffer : 100000,eps = 0.002
# n_episode :41500, score : 143.2, n_buffer : 100000,eps = 0.002
# n_episode :41600, score : 107.5, n_buffer : 100000,eps = 0.002
# n_episode :41700, score : 107.7, n_buffer : 100000,eps = 0.002
# n_episode :41800, score : 130.0, n_buffer : 100000,eps = 0.002
# n_episode :41900, score : 143.1, n_buffer : 100000,eps = 0.002
# n_episode :42000, score : 135.2, n_buffer : 100000,eps = 0.002
# n_episode :42100, score : 141.7, n_buffer : 100000,eps = 0.002
# n_episode :42200, score : 112.7, n_buffer : 100000,eps = 0.002
# n_episode :42300, score : 109.1, n_buffer : 100000,eps = 0.002
# n_episode :42400, score : 130.0, n_buffer : 100000,eps = 0.002
# n_episode :42500, score : 132.4, n_buffer : 100000,eps = 0.002
# n_episode :42600, score : 150.2, n_buffer : 100000,eps = 0.002
# n_episode :42700, score : 113.0, n_buffer : 100000,eps = 0.002
# n_episode :42800, score : 163.1, n_buffer : 100000,eps = 0.002
# n_episode :42900, score : 169.5, n_buffer : 100000,eps = 0.002
# n_episode :43000, score : 199.4, n_buffer : 100000,eps = 0.002
# n_episode :43100, score : 136.6, n_buffer : 100000,eps = 0.002
# n_episode :43200, score : 98.7, n_buffer : 100000,eps = 0.002
# n_episode :43300, score : 102.9, n_buffer : 100000,eps = 0.002
# n_episode :43400, score : 131.8, n_buffer : 100000,eps = 0.002
# n_episode :43500, score : 104.2, n_buffer : 100000,eps = 0.002
# n_episode :43600, score : 118.8, n_buffer : 100000,eps = 0.002
# n_episode :43700, score : 122.4, n_buffer : 100000,eps = 0.002
# n_episode :43800, score : 127.9, n_buffer : 100000,eps = 0.002
# n_episode :43900, score : 134.1, n_buffer : 100000,eps = 0.002
# n_episode :44000, score : 135.5, n_buffer : 100000,eps = 0.002
# n_episode :44100, score : 152.5, n_buffer : 100000,eps = 0.002
# n_episode :44200, score : 144.6, n_buffer : 100000,eps = 0.002
# n_episode :44300, score : 138.8, n_buffer : 100000,eps = 0.002
# n_episode :44400, score : 115.5, n_buffer : 100000,eps = 0.002
# n_episode :44500, score : 139.9, n_buffer : 100000,eps = 0.002
# n_episode :44600, score : 147.8, n_buffer : 100000,eps = 0.002
# n_episode :44700, score : 140.2, n_buffer : 100000,eps = 0.002
# n_episode :44800, score : 143.7, n_buffer : 100000,eps = 0.002
# n_episode :44900, score : 145.3, n_buffer : 100000,eps = 0.002
# n_episode :45000, score : 115.6, n_buffer : 100000,eps = 0.002
# n_episode :45100, score : 100.0, n_buffer : 100000,eps = 0.002
# n_episode :45200, score : 107.5, n_buffer : 100000,eps = 0.002
# n_episode :45300, score : 78.5, n_buffer : 100000,eps = 0.002
# n_episode :45400, score : 81.9, n_buffer : 100000,eps = 0.002
# n_episode :45500, score : 96.0, n_buffer : 100000,eps = 0.002
# n_episode :45600, score : 102.5, n_buffer : 100000,eps = 0.002
# n_episode :45700, score : 113.7, n_buffer : 100000,eps = 0.002
# n_episode :45800, score : 103.3, n_buffer : 100000,eps = 0.002
# n_episode :45900, score : 101.2, n_buffer : 100000,eps = 0.002
# n_episode :46000, score : 84.8, n_buffer : 100000,eps = 0.002
# n_episode :46100, score : 100.5, n_buffer : 100000,eps = 0.002
# n_episode :46200, score : 98.4, n_buffer : 100000,eps = 0.002
# n_episode :46300, score : 111.0, n_buffer : 100000,eps = 0.002
# n_episode :46400, score : 139.8, n_buffer : 100000,eps = 0.002
# n_episode :46500, score : 144.3, n_buffer : 100000,eps = 0.002
# n_episode :46600, score : 143.5, n_buffer : 100000,eps = 0.002
# n_episode :46700, score : 129.9, n_buffer : 100000,eps = 0.002
# n_episode :46800, score : 135.4, n_buffer : 100000,eps = 0.002
# n_episode :46900, score : 131.1, n_buffer : 100000,eps = 0.002
# n_episode :47000, score : 155.5, n_buffer : 100000,eps = 0.002
# n_episode :47100, score : 165.5, n_buffer : 100000,eps = 0.002
# n_episode :47200, score : 179.2, n_buffer : 100000,eps = 0.002
# n_episode :47300, score : 131.3, n_buffer : 100000,eps = 0.002
# n_episode :47400, score : 99.5, n_buffer : 100000,eps = 0.002
# n_episode :47500, score : 95.9, n_buffer : 100000,eps = 0.002
# n_episode :47600, score : 116.9, n_buffer : 100000,eps = 0.002
# n_episode :47700, score : 117.7, n_buffer : 100000,eps = 0.002
# n_episode :47800, score : 100.1, n_buffer : 100000,eps = 0.002
# n_episode :47900, score : 99.7, n_buffer : 100000,eps = 0.002
# n_episode :48000, score : 69.1, n_buffer : 100000,eps = 0.002
# n_episode :48100, score : 90.6, n_buffer : 100000,eps = 0.002
# n_episode :48200, score : 80.8, n_buffer : 100000,eps = 0.002
# n_episode :48300, score : 123.5, n_buffer : 100000,eps = 0.002
# n_episode :48400, score : 121.4, n_buffer : 100000,eps = 0.002
# n_episode :48500, score : 117.6, n_buffer : 100000,eps = 0.002
# n_episode :48600, score : 137.7, n_buffer : 100000,eps = 0.002
# n_episode :48700, score : 111.2, n_buffer : 100000,eps = 0.002
# n_episode :48800, score : 104.5, n_buffer : 100000,eps = 0.002
# n_episode :48900, score : 131.5, n_buffer : 100000,eps = 0.002
# n_episode :49000, score : 95.7, n_buffer : 100000,eps = 0.002
# n_episode :49100, score : 96.8, n_buffer : 100000,eps = 0.002
# n_episode :49200, score : 121.8, n_buffer : 100000,eps = 0.002
# n_episode :49300, score : 114.5, n_buffer : 100000,eps = 0.002
# n_episode :49400, score : 124.6, n_buffer : 100000,eps = 0.002
# n_episode :49500, score : 136.5, n_buffer : 100000,eps = 0.002
# n_episode :49600, score : 130.3, n_buffer : 100000,eps = 0.002
# n_episode :49700, score : 151.0, n_buffer : 100000,eps = 0.002
# n_episode :49800, score : 113.7, n_buffer : 100000,eps = 0.002
# n_episode :49900, score : 91.0, n_buffer : 100000,eps = 0.002
# n_episode :50000, score : 127.3, n_buffer : 100000,eps = 0.002
# n_episode :50100, score : 113.4, n_buffer : 100000,eps = 0.002
# n_episode :50200, score : 135.6, n_buffer : 100000,eps = 0.002
# n_episode :50300, score : 145.6, n_buffer : 100000,eps = 0.002
# n_episode :50400, score : 106.0, n_buffer : 100000,eps = 0.002
# n_episode :50500, score : 88.2, n_buffer : 100000,eps = 0.002
# n_episode :50600, score : 102.1, n_buffer : 100000,eps = 0.002
# n_episode :50700, score : 136.4, n_buffer : 100000,eps = 0.002
# n_episode :50800, score : 123.7, n_buffer : 100000,eps = 0.002
# n_episode :50900, score : 131.1, n_buffer : 100000,eps = 0.002
# n_episode :51000, score : 163.9, n_buffer : 100000,eps = 0.002
# n_episode :51100, score : 148.2, n_buffer : 100000,eps = 0.002
# n_episode :51200, score : 144.8, n_buffer : 100000,eps = 0.002
# n_episode :51300, score : 122.9, n_buffer : 100000,eps = 0.002
# n_episode :51400, score : 124.1, n_buffer : 100000,eps = 0.002
# n_episode :51500, score : 124.7, n_buffer : 100000,eps = 0.002
# n_episode :51600, score : 142.6, n_buffer : 100000,eps = 0.002
# n_episode :51700, score : 126.9, n_buffer : 100000,eps = 0.002
# n_episode :51800, score : 141.8, n_buffer : 100000,eps = 0.002
# n_episode :51900, score : 129.7, n_buffer : 100000,eps = 0.002
# n_episode :52000, score : 127.3, n_buffer : 100000,eps = 0.002
# n_episode :52100, score : 136.9, n_buffer : 100000,eps = 0.002
# n_episode :52200, score : 141.5, n_buffer : 100000,eps = 0.002
# n_episode :52300, score : 147.0, n_buffer : 100000,eps = 0.002
# n_episode :52400, score : 222.2, n_buffer : 100000,eps = 0.002
# n_episode :52500, score : 185.9, n_buffer : 100000,eps = 0.002
# n_episode :52600, score : 137.8, n_buffer : 100000,eps = 0.002
# n_episode :52700, score : 168.2, n_buffer : 100000,eps = 0.002
# n_episode :52800, score : 170.0, n_buffer : 100000,eps = 0.002
# n_episode :52900, score : 161.8, n_buffer : 100000,eps = 0.002
# n_episode :53000, score : 193.2, n_buffer : 100000,eps = 0.002
# n_episode :53100, score : 171.0, n_buffer : 100000,eps = 0.002
# n_episode :53200, score : 129.8, n_buffer : 100000,eps = 0.002
# n_episode :53300, score : 146.6, n_buffer : 100000,eps = 0.002
# n_episode :53400, score : 137.3, n_buffer : 100000,eps = 0.002
# n_episode :53500, score : 146.8, n_buffer : 100000,eps = 0.002
# n_episode :53600, score : 164.7, n_buffer : 100000,eps = 0.002
# n_episode :53700, score : 144.1, n_buffer : 100000,eps = 0.002
# n_episode :53800, score : 169.6, n_buffer : 100000,eps = 0.002
# n_episode :53900, score : 153.7, n_buffer : 100000,eps = 0.002
# n_episode :54000, score : 150.0, n_buffer : 100000,eps = 0.002
# n_episode :54100, score : 132.6, n_buffer : 100000,eps = 0.002
# n_episode :54200, score : 166.6, n_buffer : 100000,eps = 0.002
# n_episode :54300, score : 159.8, n_buffer : 100000,eps = 0.002
# n_episode :54400, score : 144.3, n_buffer : 100000,eps = 0.002
# n_episode :54500, score : 150.8, n_buffer : 100000,eps = 0.002
# n_episode :54600, score : 138.7, n_buffer : 100000,eps = 0.002
# n_episode :54700, score : 149.2, n_buffer : 100000,eps = 0.002
# n_episode :54800, score : 150.8, n_buffer : 100000,eps = 0.002
# n_episode :54900, score : 174.0, n_buffer : 100000,eps = 0.002
# n_episode :55000, score : 134.9, n_buffer : 100000,eps = 0.002
# n_episode :55100, score : 146.3, n_buffer : 100000,eps = 0.002
# n_episode :55200, score : 134.7, n_buffer : 100000,eps = 0.002
# n_episode :55300, score : 165.0, n_buffer : 100000,eps = 0.002
# n_episode :55400, score : 83.7, n_buffer : 100000,eps = 0.002
# n_episode :55500, score : 127.0, n_buffer : 100000,eps = 0.002
# n_episode :55600, score : 151.7, n_buffer : 100000,eps = 0.002
# n_episode :55700, score : 169.0, n_buffer : 100000,eps = 0.002
# n_episode :55800, score : 177.5, n_buffer : 100000,eps = 0.002
# n_episode :55900, score : 149.1, n_buffer : 100000,eps = 0.002
# n_episode :56000, score : 157.0, n_buffer : 100000,eps = 0.002
# n_episode :56100, score : 123.9, n_buffer : 100000,eps = 0.002
# n_episode :56200, score : 136.9, n_buffer : 100000,eps = 0.002
# n_episode :56300, score : 140.0, n_buffer : 100000,eps = 0.002
# n_episode :56400, score : 150.6, n_buffer : 100000,eps = 0.002
# n_episode :56500, score : 166.2, n_buffer : 100000,eps = 0.002
# n_episode :56600, score : 136.4, n_buffer : 100000,eps = 0.002
# n_episode :56700, score : 113.5, n_buffer : 100000,eps = 0.002
# n_episode :56800, score : 117.3, n_buffer : 100000,eps = 0.002
# n_episode :56900, score : 149.4, n_buffer : 100000,eps = 0.002
# n_episode :57000, score : 120.3, n_buffer : 100000,eps = 0.002
# n_episode :57100, score : 91.7, n_buffer : 100000,eps = 0.002
# n_episode :57200, score : 109.1, n_buffer : 100000,eps = 0.002
# n_episode :57300, score : 131.2, n_buffer : 100000,eps = 0.002
# n_episode :57400, score : 123.6, n_buffer : 100000,eps = 0.002
# n_episode :57500, score : 163.7, n_buffer : 100000,eps = 0.002
# n_episode :57600, score : 169.6, n_buffer : 100000,eps = 0.002
# n_episode :57700, score : 111.6, n_buffer : 100000,eps = 0.002
# n_episode :57800, score : 129.4, n_buffer : 100000,eps = 0.002
# n_episode :57900, score : 107.2, n_buffer : 100000,eps = 0.002
# n_episode :58000, score : 132.2, n_buffer : 100000,eps = 0.002
# n_episode :58100, score : 99.1, n_buffer : 100000,eps = 0.002
# n_episode :58200, score : 110.4, n_buffer : 100000,eps = 0.002
# n_episode :58300, score : 117.2, n_buffer : 100000,eps = 0.002
# n_episode :58400, score : 123.7, n_buffer : 100000,eps = 0.002
# n_episode :58500, score : 112.8, n_buffer : 100000,eps = 0.002
# n_episode :58600, score : 125.2, n_buffer : 100000,eps = 0.002
# n_episode :58700, score : 111.2, n_buffer : 100000,eps = 0.002
# n_episode :58800, score : 119.8, n_buffer : 100000,eps = 0.002
# n_episode :58900, score : 93.4, n_buffer : 100000,eps = 0.002
# n_episode :59000, score : 66.4, n_buffer : 100000,eps = 0.002
# n_episode :59100, score : 133.9, n_buffer : 100000,eps = 0.002
# n_episode :59200, score : 152.0, n_buffer : 100000,eps = 0.002
# n_episode :59300, score : 149.9, n_buffer : 100000,eps = 0.002
# n_episode :59400, score : 121.2, n_buffer : 100000,eps = 0.002
# n_episode :59500, score : 133.8, n_buffer : 100000,eps = 0.002
# n_episode :59600, score : 139.3, n_buffer : 100000,eps = 0.002
# n_episode :59700, score : 143.4, n_buffer : 100000,eps = 0.002
# n_episode :59800, score : 140.2, n_buffer : 100000,eps = 0.002
# n_episode :59900, score : 113.8, n_buffer : 100000,eps = 0.002
# n_episode :60000, score : 107.0, n_buffer : 100000,eps = 0.002
# n_episode :60100, score : 111.9, n_buffer : 100000,eps = 0.002
# n_episode :60200, score : 117.8, n_buffer : 100000,eps = 0.002
# n_episode :60300, score : 130.7, n_buffer : 100000,eps = 0.002
# n_episode :60400, score : 108.7, n_buffer : 100000,eps = 0.002
# n_episode :60500, score : 135.0, n_buffer : 100000,eps = 0.002
# n_episode :60600, score : 100.9, n_buffer : 100000,eps = 0.002
# n_episode :60700, score : 85.1, n_buffer : 100000,eps = 0.002
# n_episode :60800, score : 105.9, n_buffer : 100000,eps = 0.002
# n_episode :60900, score : 118.8, n_buffer : 100000,eps = 0.002
# n_episode :61000, score : 129.5, n_buffer : 100000,eps = 0.002
# n_episode :61100, score : 106.3, n_buffer : 100000,eps = 0.002
# n_episode :61200, score : 126.9, n_buffer : 100000,eps = 0.002
# n_episode :61300, score : 95.3, n_buffer : 100000,eps = 0.002
# n_episode :61400, score : 125.2, n_buffer : 100000,eps = 0.002
# n_episode :61500, score : 110.0, n_buffer : 100000,eps = 0.002
# n_episode :61600, score : 93.9, n_buffer : 100000,eps = 0.002
# n_episode :61700, score : 75.9, n_buffer : 100000,eps = 0.002
# n_episode :61800, score : 93.6, n_buffer : 100000,eps = 0.002
# n_episode :61900, score : 110.2, n_buffer : 100000,eps = 0.002
# n_episode :62000, score : 132.3, n_buffer : 100000,eps = 0.002
# n_episode :62100, score : 107.1, n_buffer : 100000,eps = 0.002
# n_episode :62200, score : 99.0, n_buffer : 100000,eps = 0.002
# n_episode :62300, score : 150.0, n_buffer : 100000,eps = 0.002
# n_episode :62400, score : 111.2, n_buffer : 100000,eps = 0.002
# n_episode :62500, score : 115.8, n_buffer : 100000,eps = 0.002
# n_episode :62600, score : 118.7, n_buffer : 100000,eps = 0.002
# n_episode :62700, score : 103.6, n_buffer : 100000,eps = 0.002
# n_episode :62800, score : 128.1, n_buffer : 100000,eps = 0.002
# n_episode :62900, score : 93.9, n_buffer : 100000,eps = 0.002
# n_episode :63000, score : 113.5, n_buffer : 100000,eps = 0.002
# n_episode :63100, score : 79.2, n_buffer : 100000,eps = 0.002
# n_episode :63200, score : 107.3, n_buffer : 100000,eps = 0.002
# n_episode :63300, score : 108.7, n_buffer : 100000,eps = 0.002
# n_episode :63400, score : 117.3, n_buffer : 100000,eps = 0.002
# n_episode :63500, score : 142.7, n_buffer : 100000,eps = 0.002
# n_episode :63600, score : 134.9, n_buffer : 100000,eps = 0.002
# n_episode :63700, score : 120.7, n_buffer : 100000,eps = 0.002
# n_episode :63800, score : 129.4, n_buffer : 100000,eps = 0.002
# n_episode :63900, score : 129.4, n_buffer : 100000,eps = 0.002
# n_episode :64000, score : 116.1, n_buffer : 100000,eps = 0.002
# n_episode :64100, score : 170.6, n_buffer : 100000,eps = 0.002
# n_episode :64200, score : 153.0, n_buffer : 100000,eps = 0.002
# n_episode :64300, score : 137.6, n_buffer : 100000,eps = 0.002
# n_episode :64400, score : 119.8, n_buffer : 100000,eps = 0.002
# n_episode :64500, score : 149.9, n_buffer : 100000,eps = 0.002
# n_episode :64600, score : 151.0, n_buffer : 100000,eps = 0.002
# n_episode :64700, score : 146.5, n_buffer : 100000,eps = 0.002
# n_episode :64800, score : 140.8, n_buffer : 100000,eps = 0.002
# n_episode :64900, score : 171.0, n_buffer : 100000,eps = 0.002
# n_episode :65000, score : 127.5, n_buffer : 100000,eps = 0.002
# n_episode :65100, score : 150.4, n_buffer : 100000,eps = 0.002
# n_episode :65200, score : 125.8, n_buffer : 100000,eps = 0.002
# n_episode :65300, score : 149.4, n_buffer : 100000,eps = 0.002
# n_episode :65400, score : 129.3, n_buffer : 100000,eps = 0.002
# n_episode :65500, score : 93.3, n_buffer : 100000,eps = 0.002
# n_episode :65600, score : 135.3, n_buffer : 100000,eps = 0.002
# n_episode :65700, score : 81.7, n_buffer : 100000,eps = 0.002
# n_episode :65800, score : 106.2, n_buffer : 100000,eps = 0.002
# n_episode :65900, score : 87.2, n_buffer : 100000,eps = 0.002
# n_episode :66000, score : 103.0, n_buffer : 100000,eps = 0.002
# n_episode :66100, score : 119.4, n_buffer : 100000,eps = 0.002
# n_episode :66200, score : 110.3, n_buffer : 100000,eps = 0.002
# n_episode :66300, score : 120.3, n_buffer : 100000,eps = 0.002
# n_episode :66400, score : 83.7, n_buffer : 100000,eps = 0.002
# n_episode :66500, score : 94.8, n_buffer : 100000,eps = 0.002
# n_episode :66600, score : 119.2, n_buffer : 100000,eps = 0.002
# n_episode :66700, score : 129.2, n_buffer : 100000,eps = 0.002
# n_episode :66800, score : 116.0, n_buffer : 100000,eps = 0.002
# n_episode :66900, score : 91.5, n_buffer : 100000,eps = 0.002
# n_episode :67000, score : 135.0, n_buffer : 100000,eps = 0.002
# n_episode :67100, score : 154.4, n_buffer : 100000,eps = 0.002
# n_episode :67200, score : 155.8, n_buffer : 100000,eps = 0.002
# n_episode :67300, score : 123.3, n_buffer : 100000,eps = 0.002
# n_episode :67400, score : 155.9, n_buffer : 100000,eps = 0.002
# n_episode :67500, score : 137.7, n_buffer : 100000,eps = 0.002
# n_episode :67600, score : 138.1, n_buffer : 100000,eps = 0.002
# n_episode :67700, score : 135.0, n_buffer : 100000,eps = 0.002
# n_episode :67800, score : 142.4, n_buffer : 100000,eps = 0.002
# n_episode :67900, score : 157.7, n_buffer : 100000,eps = 0.002
# n_episode :68000, score : 161.8, n_buffer : 100000,eps = 0.002
# n_episode :68100, score : 136.2, n_buffer : 100000,eps = 0.002
# n_episode :68200, score : 131.7, n_buffer : 100000,eps = 0.002
# n_episode :68300, score : 98.0, n_buffer : 100000,eps = 0.002
# n_episode :68400, score : 140.3, n_buffer : 100000,eps = 0.002
# n_episode :68500, score : 144.3, n_buffer : 100000,eps = 0.002
# n_episode :68600, score : 132.4, n_buffer : 100000,eps = 0.002
# n_episode :68700, score : 160.5, n_buffer : 100000,eps = 0.002
# n_episode :68800, score : 175.8, n_buffer : 100000,eps = 0.002
# n_episode :68900, score : 179.2, n_buffer : 100000,eps = 0.002
# n_episode :69000, score : 148.6, n_buffer : 100000,eps = 0.002
# n_episode :69100, score : 156.7, n_buffer : 100000,eps = 0.002
# n_episode :69200, score : 186.7, n_buffer : 100000,eps = 0.002
# n_episode :69300, score : 158.6, n_buffer : 100000,eps = 0.002
# n_episode :69400, score : 129.2, n_buffer : 100000,eps = 0.002
# n_episode :69500, score : 133.0, n_buffer : 100000,eps = 0.002
# n_episode :69600, score : 161.8, n_buffer : 100000,eps = 0.002
# n_episode :69700, score : 121.4, n_buffer : 100000,eps = 0.002
# n_episode :69800, score : 140.8, n_buffer : 100000,eps = 0.002
# n_episode :69900, score : 146.8, n_buffer : 100000,eps = 0.002
# n_episode :70000, score : 151.4, n_buffer : 100000,eps = 0.002
# n_episode :70100, score : 164.1, n_buffer : 100000,eps = 0.002
# n_episode :70200, score : 174.2, n_buffer : 100000,eps = 0.002
# n_episode :70300, score : 182.0, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  1580
# n_episode :70400, score : 173.8, n_buffer : 100000,eps = 0.002
# n_episode :70500, score : 153.3, n_buffer : 100000,eps = 0.002
# n_episode :70600, score : 150.5, n_buffer : 100000,eps = 0.002
# n_episode :70700, score : 161.9, n_buffer : 100000,eps = 0.002
# n_episode :70800, score : 140.3, n_buffer : 100000,eps = 0.002
# n_episode :70900, score : 176.7, n_buffer : 100000,eps = 0.002
# n_episode :71000, score : 148.0, n_buffer : 100000,eps = 0.002
# n_episode :71100, score : 119.7, n_buffer : 100000,eps = 0.002
# n_episode :71200, score : 162.2, n_buffer : 100000,eps = 0.002
# n_episode :71300, score : 146.2, n_buffer : 100000,eps = 0.002
# n_episode :71400, score : 161.1, n_buffer : 100000,eps = 0.002
# n_episode :71500, score : 158.7, n_buffer : 100000,eps = 0.002
# n_episode :71600, score : 163.9, n_buffer : 100000,eps = 0.002
# n_episode :71700, score : 160.2, n_buffer : 100000,eps = 0.002
# n_episode :71800, score : 118.2, n_buffer : 100000,eps = 0.002
# n_episode :71900, score : 131.7, n_buffer : 100000,eps = 0.002
# n_episode :72000, score : 124.2, n_buffer : 100000,eps = 0.002
# n_episode :72100, score : 158.8, n_buffer : 100000,eps = 0.002
# n_episode :72200, score : 161.2, n_buffer : 100000,eps = 0.002
# n_episode :72300, score : 164.8, n_buffer : 100000,eps = 0.002
# n_episode :72400, score : 128.8, n_buffer : 100000,eps = 0.002
# n_episode :72500, score : 136.7, n_buffer : 100000,eps = 0.002
# n_episode :72600, score : 155.4, n_buffer : 100000,eps = 0.002
# n_episode :72700, score : 148.8, n_buffer : 100000,eps = 0.002
# n_episode :72800, score : 187.6, n_buffer : 100000,eps = 0.002
# n_episode :72900, score : 152.9, n_buffer : 100000,eps = 0.002
# n_episode :73000, score : 111.5, n_buffer : 100000,eps = 0.002
# n_episode :73100, score : 122.7, n_buffer : 100000,eps = 0.002
# n_episode :73200, score : 161.8, n_buffer : 100000,eps = 0.002
# n_episode :73300, score : 116.4, n_buffer : 100000,eps = 0.002
# ...
# n_episode :124800, score : 116.9, n_buffer : 100000,eps = 0.002
# n_episode :124900, score : 117.4, n_buffer : 100000,eps = 0.002
# n_episode :125000, score : 99.7, n_buffer : 100000,eps = 0.002
# n_episode :125100, score : 104.9, n_buffer : 100000,eps = 0.002
# n_episode :125200, score : 149.9, n_buffer : 100000,eps = 0.002
# n_episode :125300, score : 165.1, n_buffer : 100000,eps = 0.002
# n_episode :125400, score : 148.2, n_buffer : 100000,eps = 0.002
# n_episode :125500, score : 143.6, n_buffer : 100000,eps = 0.002
# n_episode :125600, score : 121.6, n_buffer : 100000,eps = 0.002
# n_episode :125700, score : 168.0, n_buffer : 100000,eps = 0.002
# n_episode :125800, score : 129.9, n_buffer : 100000,eps = 0.002
# n_episode :125900, score : 164.9, n_buffer : 100000,eps = 0.002
# n_episode :126000, score : 178.9, n_buffer : 100000,eps = 0.002
# n_episode :126100, score : 114.0, n_buffer : 100000,eps = 0.002
# n_episode :126200, score : 171.8, n_buffer : 100000,eps = 0.002
# n_episode :126300, score : 143.9, n_buffer : 100000,eps = 0.002
# n_episode :126400, score : 152.0, n_buffer : 100000,eps = 0.002
# n_episode :126500, score : 138.8, n_buffer : 100000,eps = 0.002
# n_episode :126600, score : 136.3, n_buffer : 100000,eps = 0.002
# n_episode :126700, score : 142.6, n_buffer : 100000,eps = 0.002
# n_episode :126800, score : 158.8, n_buffer : 100000,eps = 0.002
# n_episode :126900, score : 161.5, n_buffer : 100000,eps = 0.002
# n_episode :127000, score : 151.5, n_buffer : 100000,eps = 0.002
# n_episode :127100, score : 148.4, n_buffer : 100000,eps = 0.002
# n_episode :127200, score : 106.3, n_buffer : 100000,eps = 0.002
# n_episode :127300, score : 104.2, n_buffer : 100000,eps = 0.002
# n_episode :127400, score : 137.8, n_buffer : 100000,eps = 0.002
# n_episode :127500, score : 148.5, n_buffer : 100000,eps = 0.002
# n_episode :127600, score : 138.7, n_buffer : 100000,eps = 0.002
# ...save model...
# best score :  1878
# n_episode :127700, score : 191.6, n_buffer : 100000,eps = 0.002
# n_episode :127800, score : 147.9, n_buffer : 100000,eps = 0.002
# n_episode :127900, score : 139.8, n_buffer : 100000,eps = 0.002
# n_episode :128000, score : 144.8, n_buffer : 100000,eps = 0.002
# n_episode :128100, score : 139.6, n_buffer : 100000,eps = 0.002
# n_episode :128200, score : 155.4, n_buffer : 100000,eps = 0.002
# n_episode :128300, score : 150.9, n_buffer : 100000,eps = 0.002
# n_episode :128400, score : 159.9, n_buffer : 100000,eps = 0.002
# n_episode :128500, score : 140.6, n_buffer : 100000,eps = 0.002
# n_episode :128600, score : 147.5, n_buffer : 100000,eps = 0.002
# n_episode :128700, score : 142.2, n_buffer : 100000,eps = 0.002
# n_episode :128800, score : 157.6, n_buffer : 100000,eps = 0.002
# n_episode :128900, score : 154.3, n_buffer : 100000,eps = 0.002
# n_episode :129000, score : 171.2, n_buffer : 100000,eps = 0.002
# n_episode :129100, score : 184.2, n_buffer : 100000,eps = 0.002
# n_episode :129200, score : 206.2, n_buffer : 100000,eps = 0.002
# n_episode :129300, score : 113.2, n_buffer : 100000,eps = 0.002
# n_episode :129400, score : 152.1, n_buffer : 100000,eps = 0.002
# n_episode :129500, score : 133.9, n_buffer : 100000,eps = 0.002
# n_episode :129600, score : 142.0, n_buffer : 100000,eps = 0.002
# n_episode :129700, score : 148.9, n_buffer : 100000,eps = 0.002
# n_episode :129800, score : 148.3, n_buffer : 100000,eps = 0.002
# n_episode :129900, score : 131.1, n_buffer : 100000,eps = 0.002
# n_episode :130000, score : 120.5, n_buffer : 100000,eps = 0.002
# n_episode :130100, score : 116.1, n_buffer : 100000,eps = 0.002
# n_episode :130200, score : 114.9, n_buffer : 100000,eps = 0.002
# n_episode :130300, score : 114.8, n_buffer : 100000,eps = 0.002
# n_episode :130400, score : 102.2, n_buffer : 100000,eps = 0.002
# n_episode :130500, score : 96.6, n_buffer : 100000,eps = 0.002
# n_episode :130600, score : 115.4, n_buffer : 100000,eps = 0.002
# n_episode :130700, score : 136.1, n_buffer : 100000,eps = 0.002
# n_episode :130800, score : 136.1, n_buffer : 100000,eps = 0.002
# n_episode :130900, score : 147.6, n_buffer : 100000,eps = 0.002
# n_episode :131000, score : 105.5, n_buffer : 100000,eps = 0.002
# n_episode :131100, score : 147.7, n_buffer : 100000,eps = 0.002
# n_episode :131200, score : 108.5, n_buffer : 100000,eps = 0.002
# n_episode :131300, score : 141.3, n_buffer : 100000,eps = 0.002
# n_episode :131400, score : 125.9, n_buffer : 100000,eps = 0.002
# n_episode :131500, score : 121.9, n_buffer : 100000,eps = 0.002
# n_episode :131600, score : 159.4, n_buffer : 100000,eps = 0.002
# n_episode :131700, score : 122.5, n_buffer : 100000,eps = 0.002
# n_episode :131800, score : 101.8, n_buffer : 100000,eps = 0.002
# n_episode :131900, score : 103.7, n_buffer : 100000,eps = 0.002
# n_episode :132000, score : 164.8, n_buffer : 100000,eps = 0.002
# n_episode :132100, score : 143.0, n_buffer : 100000,eps = 0.002
# n_episode :132200, score : 182.0, n_buffer : 100000,eps = 0.002
# n_episode :132300, score : 120.3, n_buffer : 100000,eps = 0.002
# n_episode :132400, score : 204.4, n_buffer : 100000,eps = 0.002
# n_episode :132500, score : 231.1, n_buffer : 100000,eps = 0.002
# n_episode :132600, score : 140.6, n_buffer : 100000,eps = 0.002
# n_episode :132700, score : 116.9, n_buffer : 100000,eps = 0.002
# n_episode :132800, score : 122.7, n_buffer : 100000,eps = 0.002
# n_episode :132900, score : 132.6, n_buffer : 100000,eps = 0.002
# n_episode :133000, score : 162.9, n_buffer : 100000,eps = 0.002
# n_episode :133100, score : 160.7, n_buffer : 100000,eps = 0.002
# n_episode :133200, score : 171.2, n_buffer : 100000,eps = 0.002
# n_episode :133300, score : 172.0, n_buffer : 100000,eps = 0.002
# n_episode :133400, score : 144.1, n_buffer : 100000,eps = 0.002
# n_episode :133500, score : 172.6, n_buffer : 100000,eps = 0.002
# n_episode :133600, score : 121.4, n_buffer : 100000,eps = 0.002
# n_episode :133700, score : 205.5, n_buffer : 100000,eps = 0.002
# n_episode :133800, score : 146.2, n_buffer : 100000,eps = 0.002
# n_episode :133900, score : 131.1, n_buffer : 100000,eps = 0.002
# n_episode :134000, score : 150.8, n_buffer : 100000,eps = 0.002
# n_episode :134100, score : 137.9, n_buffer : 100000,eps = 0.002
# n_episode :134200, score : 175.5, n_buffer : 100000,eps = 0.002
# n_episode :134300, score : 144.5, n_buffer : 100000,eps = 0.002
# n_episode :134400, score : 150.5, n_buffer : 100000,eps = 0.002
# n_episode :134500, score : 151.5, n_buffer : 100000,eps = 0.002
# n_episode :134600, score : 178.5, n_buffer : 100000,eps = 0.002
# n_episode :134700, score : 169.8, n_buffer : 100000,eps = 0.002
# n_episode :134800, score : 191.1, n_buffer : 100000,eps = 0.002
# n_episode :134900, score : 182.1, n_buffer : 100000,eps = 0.002
# n_episode :135000, score : 173.6, n_buffer : 100000,eps = 0.002
# n_episode :135100, score : 148.3, n_buffer : 100000,eps = 0.002
# n_episode :135200, score : 165.2, n_buffer : 100000,eps = 0.002
# n_episode :135300, score : 117.6, n_buffer : 100000,eps = 0.002
# n_episode :135400, score : 155.2, n_buffer : 100000,eps = 0.002
# n_episode :135500, score : 116.4, n_buffer : 100000,eps = 0.002
# n_episode :135600, score : 146.2, n_buffer : 100000,eps = 0.002
# n_episode :135700, score : 145.8, n_buffer : 100000,eps = 0.002
# n_episode :135800, score : 102.9, n_buffer : 100000,eps = 0.002
# n_episode :135900, score : 124.6, n_buffer : 100000,eps = 0.002
# n_episode :136000, score : 146.0, n_buffer : 100000,eps = 0.002
# n_episode :136100, score : 138.0, n_buffer : 100000,eps = 0.002
# n_episode :136200, score : 144.1, n_buffer : 100000,eps = 0.002
# n_episode :136300, score : 180.3, n_buffer : 100000,eps = 0.002
# n_episode :136400, score : 159.4, n_buffer : 100000,eps = 0.002
# n_episode :136500, score : 137.6, n_buffer : 100000,eps = 0.002
# n_episode :136600, score : 161.7, n_buffer : 100000,eps = 0.002
# n_episode :136700, score : 148.7, n_buffer : 100000,eps = 0.002
# n_episode :136800, score : 157.8, n_buffer : 100000,eps = 0.002
# n_episode :136900, score : 143.1, n_buffer : 100000,eps = 0.002
# n_episode :137000, score : 152.4, n_buffer : 100000,eps = 0.002
# n_episode :137100, score : 161.4, n_buffer : 100000,eps = 0.002
# n_episode :137200, score : 163.2, n_buffer : 100000,eps = 0.002
# n_episode :137300, score : 216.0, n_buffer : 100000,eps = 0.002
# n_episode :137400, score : 143.2, n_buffer : 100000,eps = 0.002
# n_episode :137500, score : 136.2, n_buffer : 100000,eps = 0.002
# n_episode :137600, score : 174.6, n_buffer : 100000,eps = 0.002
# n_episode :137700, score : 189.4, n_buffer : 100000,eps = 0.002
# n_episode :137800, score : 205.1, n_buffer : 100000,eps = 0.002
# n_episode :137900, score : 175.7, n_buffer : 100000,eps = 0.002
# n_episode :138000, score : 212.2, n_buffer : 100000,eps = 0.002
# n_episode :138100, score : 175.7, n_buffer : 100000,eps = 0.002
# n_episode :138200, score : 209.3, n_buffer : 100000,eps = 0.002
# n_episode :138300, score : 179.9, n_buffer : 100000,eps = 0.002
# n_episode :138400, score : 157.6, n_buffer : 100000,eps = 0.002
# n_episode :138500, score : 112.9, n_buffer : 100000,eps = 0.002
# n_episode :138600, score : 111.9, n_buffer : 100000,eps = 0.002
# n_episode :138700, score : 145.3, n_buffer : 100000,eps = 0.002
# n_episode :138800, score : 139.7, n_buffer : 100000,eps = 0.002
# n_episode :138900, score : 162.1, n_buffer : 100000,eps = 0.002
# n_episode :139000, score : 141.4, n_buffer : 100000,eps = 0.002
# n_episode :139100, score : 180.6, n_buffer : 100000,eps = 0.002
# n_episode :139200, score : 191.8, n_buffer : 100000,eps = 0.002
# n_episode :139300, score : 173.2, n_buffer : 100000,eps = 0.002
# n_episode :139400, score : 161.4, n_buffer : 100000,eps = 0.002
# n_episode :139500, score : 153.4, n_buffer : 100000,eps = 0.002
# n_episode :139600, score : 156.3, n_buffer : 100000,eps = 0.002
# n_episode :139700, score : 219.7, n_buffer : 100000,eps = 0.002
# n_episode :139800, score : 171.4, n_buffer : 100000,eps = 0.002
# n_episode :139900, score : 196.2, n_buffer : 100000,eps = 0.002
# n_episode :140000, score : 174.1, n_buffer : 100000,eps = 0.002
# n_episode :140100, score : 171.7, n_buffer : 100000,eps = 0.002
# n_episode :140200, score : 156.9, n_buffer : 100000,eps = 0.002
# n_episode :140300, score : 97.6, n_buffer : 100000,eps = 0.002
# n_episode :140400, score : 164.0, n_buffer : 100000,eps = 0.002
# n_episode :140500, score : 166.2, n_buffer : 100000,eps = 0.002
# n_episode :140600, score : 172.3, n_buffer : 100000,eps = 0.002
# n_episode :140700, score : 150.1, n_buffer : 100000,eps = 0.002
# n_episode :140800, score : 120.7, n_buffer : 100000,eps = 0.002
# n_episode :140900, score : 130.7, n_buffer : 100000,eps = 0.002
# n_episode :141000, score : 124.2, n_buffer : 100000,eps = 0.002
# n_episode :141100, score : 82.7, n_buffer : 100000,eps = 0.002
# n_episode :141200, score : 102.7, n_buffer : 100000,eps = 0.002
# n_episode :141300, score : 94.7, n_buffer : 100000,eps = 0.002
# n_episode :141400, score : 116.1, n_buffer : 100000,eps = 0.002
# n_episode :141500, score : 118.3, n_buffer : 100000,eps = 0.002
# n_episode :141600, score : 109.4, n_buffer : 100000,eps = 0.002
# n_episode :141700, score : 116.3, n_buffer : 100000,eps = 0.002
# n_episode :141800, score : 96.2, n_buffer : 100000,eps = 0.002
# n_episode :141900, score : 96.1, n_buffer : 100000,eps = 0.002
# n_episode :142000, score : 105.0, n_buffer : 100000,eps = 0.002
# n_episode :142100, score : 153.2, n_buffer : 100000,eps = 0.002
# n_episode :142200, score : 98.5, n_buffer : 100000,eps = 0.002
# n_episode :142300, score : 110.7, n_buffer : 100000,eps = 0.002
# n_episode :142400, score : 122.6, n_buffer : 100000,eps = 0.002
# n_episode :142500, score : 104.3, n_buffer : 100000,eps = 0.002
# n_episode :142600, score : 147.4, n_buffer : 100000,eps = 0.002
# n_episode :142700, score : 132.4, n_buffer : 100000,eps = 0.002
# n_episode :142800, score : 114.0, n_buffer : 100000,eps = 0.002
# n_episode :142900, score : 107.4, n_buffer : 100000,eps = 0.002
# n_episode :143000, score : 147.0, n_buffer : 100000,eps = 0.002
# n_episode :143100, score : 136.2, n_buffer : 100000,eps = 0.002
# n_episode :143200, score : 165.8, n_buffer : 100000,eps = 0.002
# n_episode :143300, score : 146.3, n_buffer : 100000,eps = 0.002
# n_episode :143400, score : 109.7, n_buffer : 100000,eps = 0.002
# n_episode :143500, score : 76.5, n_buffer : 100000,eps = 0.002
# n_episode :143600, score : 105.5, n_buffer : 100000,eps = 0.002
# n_episode :143700, score : 158.4, n_buffer : 100000,eps = 0.002
# n_episode :143800, score : 103.6, n_buffer : 100000,eps = 0.002
# n_episode :143900, score : 132.9, n_buffer : 100000,eps = 0.002
# n_episode :144000, score : 111.7, n_buffer : 100000,eps = 0.002
# n_episode :144100, score : 121.0, n_buffer : 100000,eps = 0.002
# n_episode :144200, score : 109.5, n_buffer : 100000,eps = 0.002
# n_episode :144300, score : 115.0, n_buffer : 100000,eps = 0.002
# n_episode :144400, score : 112.7, n_buffer : 100000,eps = 0.002
# n_episode :144500, score : 154.5, n_buffer : 100000,eps = 0.002
# n_episode :144600, score : 159.5, n_buffer : 100000,eps = 0.002
# n_episode :144700, score : 181.2, n_buffer : 100000,eps = 0.002
# n_episode :144800, score : 164.8, n_buffer : 100000,eps = 0.002
# n_episode :144900, score : 158.7, n_buffer : 100000,eps = 0.002
# n_episode :145000, score : 115.3, n_buffer : 100000,eps = 0.002
# n_episode :145100, score : 104.3, n_buffer : 100000,eps = 0.002
# n_episode :145200, score : 113.8, n_buffer : 100000,eps = 0.002
# n_episode :145300, score : 85.4, n_buffer : 100000,eps = 0.002
# n_episode :145400, score : 110.8, n_buffer : 100000,eps = 0.002
# n_episode :145500, score : 112.8, n_buffer : 100000,eps = 0.002
# n_episode :145600, score : 126.5, n_buffer : 100000,eps = 0.002
# n_episode :145700, score : 101.3, n_buffer : 100000,eps = 0.002
# n_episode :145800, score : 118.6, n_buffer : 100000,eps = 0.002
# n_episode :145900, score : 129.8, n_buffer : 100000,eps = 0.002
# n_episode :146000, score : 129.8, n_buffer : 100000,eps = 0.002
# n_episode :146100, score : 127.7, n_buffer : 100000,eps = 0.002
# n_episode :146200, score : 143.7, n_buffer : 100000,eps = 0.002
# n_episode :146300, score : 156.7, n_buffer : 100000,eps = 0.002
# n_episode :146400, score : 165.2, n_buffer : 100000,eps = 0.002
# n_episode :146500, score : 134.5, n_buffer : 100000,eps = 0.002
# n_episode :146600, score : 151.8, n_buffer : 100000,eps = 0.002
# n_episode :146700, score : 152.5, n_buffer : 100000,eps = 0.002
# n_episode :146800, score : 131.2, n_buffer : 100000,eps = 0.002
# n_episode :146900, score : 175.4, n_buffer : 100000,eps = 0.002
# n_episode :147000, score : 156.8, n_buffer : 100000,eps = 0.002
# n_episode :147100, score : 191.1, n_buffer : 100000,eps = 0.002
# n_episode :147200, score : 171.3, n_buffer : 100000,eps = 0.002
# n_episode :147300, score : 212.1, n_buffer : 100000,eps = 0.002
# n_episode :147400, score : 151.3, n_buffer : 100000,eps = 0.002
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 35
#      33     print("best score : ",best_score)
#      34 if memory.size() >10000 : #3000
# ---> 35     train(q,q_target,memory,optimizer)
#      37 if epi%100==0 and epi!=0:
#      38     q_target.load_state_dict(q.state_dict())
#
# Cell In[27], line 74, in train(q, q_target, disk, optimizer)
#      72 def train(q,q_target,disk,optimizer):
#      73     for i in range(10):
# ---> 74         s, a, r, s_prime,done_mask = disk.sampling(batch_size) # s : batch_size x 4
#      76         q_out = q(s) # current
#      77         next_q_out = q(s_prime)
#
# Cell In[27], line 45, in replay_buffer.sampling(self, bat_ch)
#      44 def sampling(self,bat_ch):
# ---> 45     mini_batch = random.sample(self.buffer,bat_ch) # bat_ch X 4 (list), dtype = tensor
#      46                                                    # buffer에서 batch_size (현재 32)만큼 sampling을 한다.
#      47     #s_list, a_list, r_prime_list, s_prime_list,done_mask_lst = [],[],[],[],[] # list로 각각을 저장할거임
#      48     a_list, r_prime_list, done_mask_lst = [],[],[]
#
# File ~/anaconda3/envs/pytorch/lib/python3.8/random.py:383, in Random.sample(self, population, k)
#     381             j = randbelow(n)
#     382         selected_add(j)
# --> 383         result[i] = population[j]
#     384 return result
#
# KeyboardInterrupt:
