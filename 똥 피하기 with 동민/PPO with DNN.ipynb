# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import random
import numpy as np
from torch.distributions import Categorical

# %%
class enva(): # player를 9로 해보자!
    def __init__(self):
        self.height = 10
        self.width = 10
        self.num_obstacle_range =5
        self.num_obstacle_range_min = 3
        self.turn = 0
        self.position = int(round(self.width/2))
        self.map = np.array([[0.0 for j in range(self.width)] for i in range(self.height)])
        self.map[self.height-1][self.position] = 2. # 2.
        self.done = False
        
    def step(self, key):
        #obstacle down
        i = self.height - 2
        while(i>=0):
            self.map[i+1] = self.map[i]
            i -= 1
        #obstacle init(first_line)
        self.map[0] = np.array([0 for j in range(self.width)])
        #obstacle making
        num_obstacle = random.randrange(self.num_obstacle_range_min,self.num_obstacle_range)
        i = 0
        while(i < num_obstacle):
            position_obstacle = random.randrange(0,self.width)
            if (self.map[0][position_obstacle] == 1.0):
                continue
            self.map[0][position_obstacle] = 1.0
            i += 1
         #big_obstacle
        big_obstacle = random.randrange(0,20)
        if(big_obstacle == -3):############### 1로 바꾸면 큰 똥이 생긴다.
            big_obstacle = random.randrange(1,self.width-1)
            for j in range(3):
                for k in range(-1,2):
                    self.map[j][big_obstacle + k] = 1.
        #player position
        reward = 1
        # 0 : 왼쪽, 1 : 가만히, 2 : 오른쪽
        if key == 0:
            if(self.position>0):
                self.position -= 1
            
        if key == 1:
            pass      
        if key == 2:
            if(self.position<self.width-1):
                self.position += 1
                  
        if (self.map[self.height-1][self.position] == 1.0):
                    reward = 0
                    self.done = True
                    #print("====Game Over====")
                        
        self.map[self.height-1][self.position] =  2. # 2.
        #reward(turn(time))
        self.turn += 1
        
        return torch.flatten(torch.tensor(self.map),0).numpy(), reward, self.done, _ 

    def reset(self):
        self.turn = 0
        self.position = round(self.width/2)
        self.map = np.array([[0.0 for j in range(self.width)] for i in range(self.height)])
        self.map[self.height-1][self.position] = 2.0
        self.done = False
        
        return torch.flatten(torch.tensor(self.map),0).numpy()

# %%
#Hyperparameters
learning_rate = 0.0005
gamma         = 0.98
lmbda         = 0.95
eps_clip      = 0.2
K_epoch       = 5
T_horizon     = 20

# %%
# PPO DNN 1 by 100

class PPO(nn.Module):
    def __init__(self):
        super(PPO, self).__init__()
        self.data = []

        self.fc0   = nn.Linear(100,128)
        self.fc1   = nn.Linear(128,128)
        self.fc2   = nn.Linear(128,128)

        self.fc4   = nn.Linear(128,128)
        self.fc_pi = nn.Linear(128,3)
        self.fc_v  = nn.Linear(128,1)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def pi(self,x, s_dim = 0):

        x = torch.flatten(x, start_dim = s_dim, end_dim = -1) ###########
        x = F.relu(self.fc0(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc4(x))
        x = self.fc_pi(x)
        prob = F.softmax(x, dim = s_dim)

        #torch.nan_to_num(prob, nan = 0.0)
        return prob
    
    def v(self, x):
        
        x = torch.flatten(x, start_dim = 1, end_dim = -1)
        
        x = F.relu(self.fc0(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc4(x))
        v = self.fc_v(x)

        return v
      
    def put_data(self, transition):
        self.data.append(transition)
        
    def make_batch(self):
        s_lst, a_lst, r_lst, s_prime_lst, prob_a_lst, done_lst = [], [], [], [], [], []

        for transition in self.data:
            s, a, r, s_prime, prob_a, done = transition
            
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            prob_a_lst.append([prob_a])
            done_mask = 0 if done else 1
            done_lst.append([done_mask])
        
        s,a,r,s_prime,done_mask, prob_a = torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
                                          torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), \
                                          torch.tensor(done_lst, dtype=torch.float), torch.tensor(prob_a_lst)
        self.data = []
        
        # num_layer X batch X hidden으로 만들기
        return s, a, r, s_prime, done_mask, prob_a
        
    def train_net(self):
        s, a, r, s_prime, done_mask, prob_a = self.make_batch()
        
        td_target = r + gamma * self.v(s_prime) * done_mask
        delta = td_target - self.v(s)
        delta = delta.detach().numpy()
        
        advantage_lst = []
        advantage = 0.0
        for delta_t in delta[::-1]:
            advantage = gamma * lmbda * advantage + delta_t[0]
            advantage_lst.append([advantage])
        advantage_lst.reverse()
        advantage = torch.tensor(advantage_lst, dtype=torch.float) 
       
        for i in range(K_epoch):
        
            pi = self.pi(s, s_dim = 1) 
            pi_a = pi.gather(1,a) 

            ratio = torch.exp(torch.log(pi_a) - torch.log(prob_a))  # a/b == exp(log(a)-log(b)) ##############

            
            surr1 = ratio * advantage
            surr2 = torch.clamp(ratio, 1-eps_clip, 1+eps_clip) * advantage
            
            loss = -torch.min(surr1, surr2) + F.smooth_l1_loss(self.v(s) , td_target.detach()) 
            
            self.optimizer.zero_grad()
            loss.mean().backward() # 여러 번 loss의 gradient를 구할 때
            self.optimizer.step()
        
def main():
    env = enva()
    model = PPO()
    #model.load_state_dict(torch.load('ppo_ddong_with_dongmin.pt'))

    score = 0.0
    print_interval = 100
    best_score = 0.0
    one_score = 0.0
    
    for n_epi in range(30000):
        s = env.reset()
        done = False
        while not done:
            for t in range(T_horizon):
                prob = model.pi(torch.from_numpy(s).float())
                
                m = Categorical(prob)
                a = m.sample().item()
                s_prime, r, done, info = env.step(a)
                
                model.put_data((s, a, r, s_prime, prob[a].item(), done))
                s = copy.deepcopy(s_prime)
                
                score += r
                one_score += r
                if done:
                    break
            
            model.train_net()
            
        if best_score <= one_score:
            best_score = one_score
        #    print("... save model ...")
            print(f"best score : {one_score}")
        #    torch.save(model.state_dict(),'ppo_ddong_with_dongmin.pt')
            
        one_score = 0
            
        if n_epi%print_interval==0 and n_epi!=0:
            print("# of episode :{}, avg score : {:.1f}".format(n_epi, score/print_interval))
            score = 0.0
    
    return best_score

if __name__ == '__main__':
    best_score = main()
    print(f"final best_score : {best_score}")
# Out:
# best score : 9.0
# best score : 9
# best score : 13
# best score : 13
# best score : 15
# best score : 25
# # of episode :100, avg score : 11.6
# # of episode :200, avg score : 10.9
# best score : 30
# # of episode :300, avg score : 11.7
# # of episode :400, avg score : 11.4
# # of episode :500, avg score : 11.5
# # of episode :600, avg score : 11.4
# best score : 32
# best score : 34
# best score : 41
# # of episode :700, avg score : 13.7
# # of episode :800, avg score : 12.7
# # of episode :900, avg score : 11.1
# # of episode :1000, avg score : 10.8
# # of episode :1100, avg score : 10.9
# # of episode :1200, avg score : 10.8
# # of episode :1300, avg score : 10.5
# # of episode :1400, avg score : 10.9
# # of episode :1500, avg score : 11.1
# # of episode :1600, avg score : 10.8
# # of episode :1700, avg score : 10.7
# # of episode :1800, avg score : 11.4
# # of episode :1900, avg score : 11.0
# # of episode :2000, avg score : 11.8
# # of episode :2100, avg score : 11.5
# # of episode :2200, avg score : 11.4
# # of episode :2300, avg score : 11.1
# # of episode :2400, avg score : 10.9
# # of episode :2500, avg score : 11.1
# # of episode :2600, avg score : 10.7
# # of episode :2700, avg score : 11.1
# # of episode :2800, avg score : 12.0
# # of episode :2900, avg score : 13.4
# best score : 48
# # of episode :3000, avg score : 13.9
# # of episode :3100, avg score : 14.8
# # of episode :3200, avg score : 14.9
# best score : 48
# # of episode :3300, avg score : 13.6
# # of episode :3400, avg score : 11.8
# # of episode :3500, avg score : 12.9
# # of episode :3600, avg score : 11.0
# # of episode :3700, avg score : 11.3
# # of episode :3800, avg score : 13.0
# # of episode :3900, avg score : 11.0
# # of episode :4000, avg score : 11.8
# # of episode :4100, avg score : 12.8
# # of episode :4200, avg score : 13.8
# # of episode :4300, avg score : 13.8
# # of episode :4400, avg score : 14.0
# # of episode :4500, avg score : 12.4
# # of episode :4600, avg score : 13.9
# # of episode :4700, avg score : 12.0
# # of episode :4800, avg score : 11.6
# # of episode :4900, avg score : 11.8
# # of episode :5000, avg score : 11.8
# # of episode :5100, avg score : 12.6
# # of episode :5200, avg score : 13.3
# # of episode :5300, avg score : 14.4
# # of episode :5400, avg score : 15.3
# # of episode :5500, avg score : 14.6
# # of episode :5600, avg score : 13.3
# # of episode :5700, avg score : 15.6
# best score : 55
# # of episode :5800, avg score : 15.7
# best score : 59
# # of episode :5900, avg score : 15.9
# best score : 65
# # of episode :6000, avg score : 17.7
# # of episode :6100, avg score : 17.8
# # of episode :6200, avg score : 16.0
# # of episode :6300, avg score : 15.3
# # of episode :6400, avg score : 16.1
# # of episode :6500, avg score : 16.2
# # of episode :6600, avg score : 17.1
# # of episode :6700, avg score : 17.0
# # of episode :6800, avg score : 16.4
# # of episode :6900, avg score : 12.2
# # of episode :7000, avg score : 14.4
# # of episode :7100, avg score : 15.0
# # of episode :7200, avg score : 16.5
# # of episode :7300, avg score : 15.8
# # of episode :7400, avg score : 15.8
# # of episode :7500, avg score : 16.2
# # of episode :7600, avg score : 16.4
# # of episode :7700, avg score : 15.3
# # of episode :7800, avg score : 15.0
# # of episode :7900, avg score : 15.8
# # of episode :8000, avg score : 16.4
# # of episode :8100, avg score : 14.3
# # of episode :8200, avg score : 15.3
# # of episode :8300, avg score : 16.3
# # of episode :8400, avg score : 16.7
# # of episode :8500, avg score : 17.9
# # of episode :8600, avg score : 18.0
# # of episode :8700, avg score : 17.7
# # of episode :8800, avg score : 15.6
# # of episode :8900, avg score : 17.4
# # of episode :9000, avg score : 17.0
# # of episode :9100, avg score : 16.1
# # of episode :9200, avg score : 17.5
# # of episode :9300, avg score : 17.5
# # of episode :9400, avg score : 18.9
# # of episode :9500, avg score : 17.7
# # of episode :9600, avg score : 17.2
# # of episode :9700, avg score : 17.6
# # of episode :9800, avg score : 17.3
# # of episode :9900, avg score : 17.3
# # of episode :10000, avg score : 18.8
# # of episode :10100, avg score : 17.3
# # of episode :10200, avg score : 17.1
# best score : 72
# # of episode :10300, avg score : 18.4
# # of episode :10400, avg score : 17.8
# # of episode :10500, avg score : 17.4
# # of episode :10600, avg score : 16.0
# # of episode :10700, avg score : 17.8
# # of episode :10800, avg score : 17.6
# # of episode :10900, avg score : 18.1
# best score : 105
# # of episode :11000, avg score : 19.7
# # of episode :11100, avg score : 18.4
# # of episode :11200, avg score : 19.1
# # of episode :11300, avg score : 19.1
# # of episode :11400, avg score : 18.0
# # of episode :11500, avg score : 18.0
# # of episode :11600, avg score : 20.6
# # of episode :11700, avg score : 21.2
# # of episode :11800, avg score : 18.6
# # of episode :11900, avg score : 18.4
# # of episode :12000, avg score : 19.3
# # of episode :12100, avg score : 18.2
# # of episode :12200, avg score : 18.2
# # of episode :12300, avg score : 18.5
# # of episode :12400, avg score : 19.8
# # of episode :12500, avg score : 20.8
# # of episode :12600, avg score : 18.3
# # of episode :12700, avg score : 19.4
# # of episode :12800, avg score : 20.3
# # of episode :12900, avg score : 19.7
# # of episode :13000, avg score : 22.0
# # of episode :13100, avg score : 22.7
# # of episode :13200, avg score : 16.6
# # of episode :13300, avg score : 12.0
# # of episode :13400, avg score : 20.4
# # of episode :13500, avg score : 17.9
# # of episode :13600, avg score : 18.9
# best score : 108
# # of episode :13700, avg score : 21.1
# # of episode :13800, avg score : 21.1
# # of episode :13900, avg score : 22.8
# # of episode :14000, avg score : 19.1
# # of episode :14100, avg score : 20.9
# # of episode :14200, avg score : 22.6
# # of episode :14300, avg score : 22.3
# # of episode :14400, avg score : 21.6
# # of episode :14500, avg score : 24.6
# # of episode :14600, avg score : 21.4
# # of episode :14700, avg score : 24.8
# # of episode :14800, avg score : 11.5
# # of episode :14900, avg score : 11.8
# # of episode :15000, avg score : 21.3
# # of episode :15100, avg score : 22.6
# # of episode :15200, avg score : 27.1
# # of episode :15300, avg score : 21.8
# # of episode :15400, avg score : 24.1
# # of episode :15500, avg score : 26.2
# # of episode :15600, avg score : 28.3
# # of episode :15700, avg score : 29.6
# # of episode :15800, avg score : 27.0
# best score : 122
# # of episode :15900, avg score : 28.6
# # of episode :16000, avg score : 29.3
# # of episode :16100, avg score : 22.2
# best score : 135
# # of episode :16200, avg score : 30.8
# # of episode :16300, avg score : 29.8
# # of episode :16400, avg score : 28.1
# # of episode :16500, avg score : 31.9
# # of episode :16600, avg score : 26.9
# # of episode :16700, avg score : 29.5
# best score : 147
# # of episode :16800, avg score : 32.7
# # of episode :16900, avg score : 28.5
# # of episode :17000, avg score : 32.2
# # of episode :17100, avg score : 29.3
# # of episode :17200, avg score : 28.6
# best score : 156
# best score : 159
# # of episode :17300, avg score : 31.5
# # of episode :17400, avg score : 29.4
# # of episode :17500, avg score : 28.0
# # of episode :17600, avg score : 32.2
# # of episode :17700, avg score : 31.7
# # of episode :17800, avg score : 32.7
# # of episode :17900, avg score : 31.6
# # of episode :18000, avg score : 35.4
# # of episode :18100, avg score : 35.8
# best score : 168
# # of episode :18200, avg score : 32.4
# # of episode :18300, avg score : 33.5
# # of episode :18400, avg score : 33.1
# # of episode :18500, avg score : 36.9
# # of episode :18600, avg score : 32.4
# # of episode :18700, avg score : 21.9
# # of episode :18800, avg score : 30.6
# # of episode :18900, avg score : 31.7
# # of episode :19000, avg score : 29.8
# # of episode :19100, avg score : 27.9
# # of episode :19200, avg score : 21.9
# # of episode :19300, avg score : 31.8
# # of episode :19400, avg score : 27.3
# # of episode :19500, avg score : 32.2
# # of episode :19600, avg score : 32.2
# # of episode :19700, avg score : 30.1
# # of episode :19800, avg score : 23.0
# # of episode :19900, avg score : 31.1
# # of episode :20000, avg score : 29.7
# best score : 173
# # of episode :20100, avg score : 31.9
# # of episode :20200, avg score : 26.1
# # of episode :20300, avg score : 30.8
# # of episode :20400, avg score : 23.7
# # of episode :20500, avg score : 22.8
# # of episode :20600, avg score : 31.9
# # of episode :20700, avg score : 27.1
# # of episode :20800, avg score : 32.9
# # of episode :20900, avg score : 33.2
# # of episode :21000, avg score : 32.2
# # of episode :21100, avg score : 27.6
# # of episode :21200, avg score : 31.8
# # of episode :21300, avg score : 26.5
# # of episode :21400, avg score : 22.2
# # of episode :21500, avg score : 33.0
# # of episode :21600, avg score : 30.5
# # of episode :21700, avg score : 21.3
# # of episode :21800, avg score : 10.6
# # of episode :21900, avg score : 10.8
# # of episode :22000, avg score : 11.2
# # of episode :22100, avg score : 10.9
# # of episode :22200, avg score : 11.1
# # of episode :22300, avg score : 11.0
# # of episode :22400, avg score : 10.6
# # of episode :22500, avg score : 10.5
# # of episode :22600, avg score : 10.8
# # of episode :22700, avg score : 10.8
# # of episode :22800, avg score : 11.1
# # of episode :22900, avg score : 10.8
# # of episode :23000, avg score : 10.4
# # of episode :23100, avg score : 10.9
# # of episode :23200, avg score : 10.6
# # of episode :23300, avg score : 10.6
# # of episode :23400, avg score : 10.8
# # of episode :23500, avg score : 11.3
# # of episode :23600, avg score : 11.0
# # of episode :23700, avg score : 10.4
# # of episode :23800, avg score : 10.8
# # of episode :23900, avg score : 11.2
# # of episode :24000, avg score : 10.4
# # of episode :24100, avg score : 11.4
# # of episode :24200, avg score : 11.2
# # of episode :24300, avg score : 10.7
# # of episode :24400, avg score : 10.8
# # of episode :24500, avg score : 11.3
# # of episode :24600, avg score : 11.3
# # of episode :24700, avg score : 10.8
# # of episode :24800, avg score : 12.7
# # of episode :24900, avg score : 12.6
# # of episode :25000, avg score : 12.5
# # of episode :25100, avg score : 12.4
# # of episode :25200, avg score : 10.9
# # of episode :25300, avg score : 10.9
# # of episode :25400, avg score : 10.7
# # of episode :25500, avg score : 11.1
# # of episode :25600, avg score : 11.9
# # of episode :25700, avg score : 11.1
# # of episode :25800, avg score : 11.0
# # of episode :25900, avg score : 11.1
# # of episode :26000, avg score : 10.8
# # of episode :26100, avg score : 11.9
# # of episode :26200, avg score : 10.7
# # of episode :26300, avg score : 10.4
# # of episode :26400, avg score : 10.8
# # of episode :26500, avg score : 11.5
# # of episode :26600, avg score : 11.7
# # of episode :26700, avg score : 10.8
# # of episode :26800, avg score : 11.2
# # of episode :26900, avg score : 10.9
# # of episode :27000, avg score : 11.6
# # of episode :27100, avg score : 11.2
# # of episode :27200, avg score : 12.5
# # of episode :27300, avg score : 12.4
# # of episode :27400, avg score : 12.1
# # of episode :27500, avg score : 12.6
# # of episode :27600, avg score : 12.4
# # of episode :27700, avg score : 11.3
# # of episode :27800, avg score : 11.9
# # of episode :27900, avg score : 11.7
# # of episode :28000, avg score : 11.1
# # of episode :28100, avg score : 11.0
# # of episode :28200, avg score : 11.1
# # of episode :28300, avg score : 10.7
# # of episode :28400, avg score : 10.8
# # of episode :28500, avg score : 10.9
# # of episode :28600, avg score : 11.6
# # of episode :28700, avg score : 11.3
# # of episode :28800, avg score : 11.5
# # of episode :28900, avg score : 12.6
# # of episode :29000, avg score : 12.1
# # of episode :29100, avg score : 12.0
# # of episode :29200, avg score : 10.4
# # of episode :29300, avg score : 11.5
# # of episode :29400, avg score : 11.6
# # of episode :29500, avg score : 11.6
# # of episode :29600, avg score : 11.2
# # of episode :29700, avg score : 11.5
# # of episode :29800, avg score : 11.1
# # of episode :29900, avg score : 11.0
# final best_score : 173

# %%
model.load_state_dict(torch.load('ppo_ddong_with_dongmin.pt'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model.load_state_dict(torch.load('ppo_ddong_with_dongmin.pt'))
#
# NameError: name 'model' is not defined

# %%
import sys
from time import sleep
import numpy as np
import random
import time
import copy

q = PPO()

q.load_state_dict(torch.load('ppo_ddong_with_dongmin.pt'))
height = 10
width = 10
num_obstacle_range =7
num_obstacle_range_min = 3
turn = 0
position = round(width/2)
player_position = round(width/2)
map = np.array([[0. for j in range(width)] for i in range(height)])
map[height-1][position] =  9. # 2.

player_map = copy.deepcopy(map)
q.eval()
with torch.no_grad():

    while True:
        #print_map
        action = q.pi(torch.flatten(torch.tensor(map).float()))
        print("===============player map==================\t\t===============ai map==================")
        for m,n in zip(player_map,map):
            print(m,end="\t\t\t\t  ")
            print(n)
            
        #print("===============ai map==================")
        #print(map)
        #print("===============player map==================")
        #print(player_map)
        print("Turn:" ,turn)
        #obstacle down
        i = height - 2
        while(i>=0):
            map[i+1] = map[i]
            i -= 1
        #obstacle init(first_line)
        map[0] = np.array([0. for j in range(width)])
        #obstacle making
        num_obstacle = random.randrange(num_obstacle_range_min,num_obstacle_range)
        i = 0
        while(i < num_obstacle):
            position_obstacle = random.randrange(0,width)
            if (map[0][position_obstacle] == 1.):
                continue
            map[0][position_obstacle] = 1.
            i += 1
        #big_obstacle
        big_obstacle = random.randrange(0,20)
        if(big_obstacle == 0):
            big_obstacle = random.randrange(1,width-1)
            for j in range(3):
                for k in range(-1,2):
                    map[j][big_obstacle + k] = 1.
        #copy player_map
        player_map = copy.deepcopy(map)
        #ai position
        #print("value : ",action)
        action = torch.argmax(action).item()
        #print("action : ", action)
        
        # check the time
        start_time = time.time()
        while True:
            
            player_key = input()
            key = action
            
            #if (time.time() - start_time) > 5:
            #    print("...Time Out!!...")
            #    break
            #else :
            #    print("Time: {:.4f}sec".format((time.time() - start_time)))
                
            # player action
            if player_key == "j":
                if(player_position>0):
                    player_position -= 1
                
            if player_key == "k":
                pass        
            if player_key == "l":
                if(player_position<width-1):
                    player_position += 1
                        

            # ai action
            if key == 0:
                if(position>0):
                    position -= 1
                break
            if key == 1:
                break        
            if key ==2:
                if(position<width-1):
                    position += 1
                break        
            
            
        if map[height-1][position] == 1 or player_map[height-1][player_position] == 1:
                    print("====Game Over====")
                    if map[height-1][position] == 1:
                        print("player win!!\n\n")
                    
                    elif player_map[height-1][player_position] == 1:
                        print("AI win!!\n\n")
                    sys.exit()    
        map[height-1][position] =  9. # 2.
        player_map[height-1][player_position] =  9. # 2.j
        #reward(turn(time))
        turn += 1
